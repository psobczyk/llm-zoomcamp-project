# %% [markdown]
# Here we evaluate the performance of the model on the test set.
#
# - documents_olx_20240823_1135 index was built using 'xlm-r-distilroberta-base-paraphrase-v1' sentence transformer model.

# %%
from sentence_transformers import SentenceTransformer
import json
from tqdm.auto import tqdm
import pandas as pd
from elasticsearch import Elasticsearch
import time
import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
with open('../data/documents-olx-2024_08_25-with-ids.json', 'rt') as f_in:
    documents = json.load(f_in)

# %%
model_name = 'xlm-r-distilroberta-base-paraphrase-v1'
model = SentenceTransformer(model_name)
# Out:
# /Users/piotr/projects/llm-zoomcamp-project/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
es_client = Elasticsearch('http://localhost:9200')

# %%
def elastic_search(query_vector, index_name = "documents_olx_20240829_5014",
                   field = 'question_text_vector'):
    
    knn = {
        "field": field,
        "query_vector": query_vector,
        "k": 5,
        "num_candidates": 10000,
    }

    search_query = {
        "knn": knn,
        "_source": ["text", "section", "question", "course", "id"],
        "min_score": 0.1,  # Optional: Minimum score threshold for results
        "sort": [{ "_score": "asc" }]  # Sort by score if applicable
    }

    es_results = es_client.search(
        index=index_name,
        body=search_query
    )
    
    result_docs = []
    
    for hit in es_results['hits']['hits']:
        result_docs.append(hit['_source'])

    return result_docs

# %%
df_ground_truth = pd.read_csv('../data/ground-truth-data_2024_08_25.csv')

# %%
ground_truth = df_ground_truth.to_dict(orient='records')

# %%
ground_truth[0]
# Out:
# {'question': 'Jak mogę założyć konto na OLX przez stronę internetową?',
#  'document': '2ddb5f16'}

# %%
def hit_rate(relevance_total):
    cnt = 0

    for line in relevance_total:
        if True in line:
            cnt = cnt + 1

    return cnt / len(relevance_total)


def mrr(relevance_total):
    total_score = 0.0

    for line in relevance_total:
        for rank in range(len(line)):
            if line[rank] == True:
                total_score = total_score + 1 / (rank + 1)

    return total_score / len(relevance_total)

# %%
def evaluate(ground_truth, search_function):
    results_total = []
    relevance_total = []

    for q in tqdm(ground_truth):
        doc_id = q['document']
        results = search_function(q)
        relevance = [d['id'] == doc_id for d in results]
        relevance_total.append(relevance)
        results_total.append(results)

    return {
        'results_total': results_total,
        'relevance_total': relevance_total,
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total),
    }

# %% [markdown]
# ES text only: 0.7395720769397017, 0.6032418413658963

# %%
ground_truth[0]
# Out:
# {'question': 'Jak mogę założyć konto na OLX przez stronę internetową?',
#  'document': '2ddb5f16'}

# %%
def question_text_vector_knn(q):
    question = q['question']

    v_q = model.encode(question)

    return elastic_search(v_q)

# %%
res = evaluate(ground_truth, question_text_vector_knn)
# Out:
# 100%|██████████| 461/461 [00:54<00:00,  8.39it/s]

# %%
print(res['hit_rate'])
print(res['mrr'])
# Out:
# 0.702819956616052
# 0.2190889370932759

# %% [markdown]
# Let's analyze when the model fails to retrieve the correct document.

# %%
missed_questions = [i for i, r in enumerate(res['relevance_total']) if not any(r)]

# %%
import random 
random.seed(10)
for i in random.sample(missed_questions, 5):
    print("Pytanie:", ground_truth[i])
    expected_doc_id = ground_truth[i]['document']
    print("Oczekiwany dokument:", [doc['question'] for doc in documents if doc['id'] == expected_doc_id])
    print("Oczekiwany dokument:", [doc['text'] for doc in documents if doc['id'] == expected_doc_id])
    
    returned_docs = res['results_total'][i]
    print("\nZnalezione dokumenty:")
    for j, doc in enumerate(returned_docs):
        print(j)
        print(doc['question'])
        print(doc['text'])
        print("\n")
    
    print("\n\n")
# Out:
# Pytanie: {'question': 'Które informacje można zmienić w zakładce Profil na koncie OLX?', 'document': '6c146627'}
# Oczekiwany dokument: ['Zmiana danych kontaktowych']
# Oczekiwany dokument: ['Krok 1. Zaloguj się na swoje konto OLX używając komputera (w aplikacji mobilnej możesz zmienić tylko nazwę osoby kontaktowej).\nKrok 2. Przejdź do zakładki Twoje konto → Profil.\nKrok 3. Kliknij przycisk Edytuj.\nKrok 4. Zmień podstawowe informacje.\nKrok 5. Kliknij przycisk Zapisz.\nPamiętaj, że gdy zmienisz dane kontaktowe, będą one widoczne wyłącznie w ogłoszeniach, które masz zamiar dodać. Jeżeli chcesz zmienić dane w ogłoszeniach już aktywnych, musisz edytować te ogłoszenia — sprawdź instrukcję.']
#
# Znalezione dokumenty:
# 0
# Czy nowy System Ocen jest dostępny we wszystkich kategoriach?
# Oceny mogą wystawiać wyłącznie użytkownicy, którzy kupili przedmiot z Przesyłką OLX — i dopiero po jej otrzymaniu. Oznacza to, że oceny mogą być wystawiane wyłącznie po odebraniu przez Kupującego przedmiotu kupionego z Przesyłką OLX (kategorie, w których Przesyłka OLX jest dostępna). Gdy sprzedający otrzyma ocenę, jest ona wyświetlana na jego profilu i we wszystkich aktywnych ogłoszeniach (również tych, które nie mają włączonej Przesyłki OLX).
# Ogłoszenia w poniższych kategoriach nie będą wyświetlać oceny sprzedającego, ponieważ dotyczą usług lub przedmiotów, których nie można dostarczyć z Przesyłką OLX:
# Usługi
# Praca
# Nieruchomości
# Motoryzacja
# Wypożyczalnia
# Oznacza to, że:
# Jeśli sprzedający doda ogłoszenie w kategorii Usługi i ogłoszenie w kategorii Elektronika, jego ocena będzie wyświetlana tylko w ogłoszeniu w kategorii Elektronika.
# Jeżeli sprzedający dodał dwa ogłoszenia w kategorii Elektronika, ale tylko jedno z nich ma włączoną Przesyłkę OLX, jego ocena pojawi się w obu ogłoszeniach.
# System Ocen jest dostępny na stronie internetowej, stronie mobilnej i w wersji 4.95.1 (lub nowszej) aplikacji OLX na urządzenia z systemem iOS oraz w wersji 5.98.2 (lub nowszej) aplikacji OLX na urządzenia z systemem Android.
#
#
# 1
# Jak założyć konto?
# Krok 1. Załóż konto na OLX poprzez:
# stronę internetową OLX — kliknij Twoje konto → Załóż konto lub kliknij tutaj.
# aplikację mobilną OLX — kliknij Konto → Zaloguj się → Załóż konto.
# Jeśli grafika jest nieczytelna, kliknij prawy przycisk myszy i wybierz „Otwórz grafikę w nowej karcie".
# Krok 2. Wpisz swój adres e-mail.
# Krok 3. Wpisz hasło, które ma minimum 8 znaków, w tym przynajmniej jedną dużą i małą literę, jedną cyfrę oraz znak specjalny.
# Krok 4. Kliknij Zarejestruj się.
# Krok 5. Przejdź do skrzynki mailowej i w wiadomości od OLX kliknij przycisk Aktywuj konto.
# Jeśli nie masz linku aktywacyjnego — napisz do nas.
# Na jednym koncie OLX nie można sprzedawać przedmiotów prywatnych i przedmiotów w ramach prowadzenia firmy. Do każdego typu sprzedaży (prywatnie, jako firma) wymagane jest oddzielne konto.
# Konto na OLX możesz założyć za pomocą konta na Facebooku. Wystarczy, że klikniesz tutaj. Następnie wybierz przycisk Kontynuuj z Facebook i postępuj zgodnie z wyświetlanymi wskazówkami. W ten sposób utworzymy konto w OLX na adresie e-mail powiązanym z Twoim kontem Facebook. Przed wyborem „Kontynuuj z Facebookiem" sprawdź, czy jesteś zalogowany/zalogowana na danym urządzeniu do konta Facebook.
#
#
# 2
# Jak OLX przetwarza dane?
# Grupa OLX przetwarza dane osobowe Użytkowników, osób działających w imieniu Użytkowników oraz Gości zgodnie z postanowieniami Polityki Prywatności oraz Polityką dotyczącą Cookies i Podobnych Technologii.
#
#
# 3
# Jak dodać ogłoszenie?
# Aby dodać ogłoszenie:
# Krok 1. Zaloguj się do swojego konta w OLX.
# Krok 2. Jeśli korzystasz z:
# strony internetowej OLX — kliknij przycisk Dodaj ogłoszenie — znajdziesz go w prawym, górnym rogu.
# aplikacji mobilnej OLX — kliknij przycisk Dodaj — znajdziesz go na dole ekranu.
# Dodaj_ogłoszenie.png
# Jeśli grafika jest nieczytelna, kliknij prawy przycisk myszy i wybierz „Otwórz grafikę w nowej karcie".
# Krok 3. Uzupełnij szczegóły ogłoszenia.
# Tytuł
# Wpisz tytuł ogłoszenia. Po słowach z tytułu ogłoszenia Użytkownicy mogą wyszukać Twoją ofertę. Pamiętaj, aby nie pisać tylko wielkimi literami.
# Kategoria
# Wybierz kategorię sprzedawanego przedmiotu samodzielnie na podstawie naszych podpowiedzi lub skorzystaj z dostępnej listy. Jeżeli chcesz się upewnić, że wybierasz odpowiednią kategorię, zajrzyj tutaj.
# Cena
# Podaj cenę. Powinna ona odzwierciedlać wartość przedmiotu. Możesz również wybrać opcję Za darmo lub Zamienię. Pamiętaj, aby w ogłoszeniu wpisać rzeczywistą, oczekiwaną kwotę całkowitą brutto (w polskiej walucie).
# Opcje „Za darmo” oraz „Zamienię” nie są dostępne w kategorii Motoryzacja, w części podkategorii Nieruchomości oraz w kategorii Rolnictwo: Ciągniki, Maszyny rolnicze, Przyczepy, Części do maszyn rolniczych, Opony rolnicze.
# W niektórych kategoriach podanie ceny nie jest możliwe — na przykład w kategoriach usługowych. Możesz wtedy zamieścić cenę usługi w treści oferty.
# Typ ogłoszenia
# Typ ogłoszenia (osoba prywatna/firma) zostanie przypisany automatycznie po złożeniu deklaracji, w jaki sposób sprzedajesz na OLX. Pamiętaj, że deklaracja jest przypisana do wszystkich Twoich ogłoszeń i jej zmiana jest niemożliwa.
# Opis
# W tym miejscu podaj wszystkie szczegóły dotyczące przedmiotu/usługi. Zadbaj o szczegółowy i przejrzysty opis. W przypadku sprzedaży przedmiotu opisz stan, użyteczność, podaj parametry oraz ewentualne wady.
# Zdjęcia
# Kliknij Dodaj zdjęcie lub kliknij symbol aparatu, aby dodać zdjęcia, które najlepiej odzwierciedlą Twój przedmiot. Zadbaj o dobrą jakość zdjęć (maksymalna wielkość to 5 MB (format 4:3) lub 1500 x 1205 pikseli. Akceptowane formaty to: jpg, jpeg, png).
# Jeżeli chcesz się dowiedzieć, jak powinny wyglądać dobre zdjęcia, zapraszamy do naszego poradnika Jak zrobić atrakcyjne zdjęcia?
# Przypominamy także, że zgodnie z naszymi Zasadami, dodane zdjęcia:
# → nie mogą pochodzić z Internetu (łamią wtedy bowiem prawa autorskie),
# → powinny przedstawiać wyłącznie oferowany przedmiot,
# → nie powinny zawierać danych kontaktowych np. numeru telefonu.
# W kategorii Praca dodanie zdjęcia nie będzie możliwe.
# Dane kontaktowe i lokalizacja
# → Wybierz miejscowość i dzielnicę, w której można obejrzeć Twój przedmiot lub w której wykonujesz usługę. Użytkownicy nie będę widzieć Twojego dokładnego adresu.
# → Wpisz osobę kontaktową — będzie ona pojawiać się w każdym ogłoszeniu, które dodasz.
# → Wskazany adres e-mail jest powiązany z kontem.
# → Numer telefonu — Użytkownicy będą kontaktować się z Tobą poprzez wiadomości OLX. Jeżeli chcesz, aby kontaktowali się z Tobą również telefonicznie — podaj swój numer telefonu. Aby podać więcej niż jeden numer telefonu — rozdziel je przecinkiem i spacją, np. „601234XXX, 601234YYY".
# Dane takie jak: adres e-mail, miejscowość, numer telefonu oraz imię osoby kontaktowej możesz uzupełnić / zmienić w zakładce Ustawienia / Dane kontaktowe. Będą one widoczne podczas dodawania kolejnych ogłoszeń.
# Dodatkowe parametry
# W części kategorii konieczne będzie dodanie dodatkowych parametrów. W kategorii Moda — rozmiar ubrania, w kategorii Praca — rodzaj umowy, a w kategorii Motoryzacja/Części samochodowe — parametry oferowanej części. Wypełnij pola oznaczone gwiazdką.
# Krok 4. Jeżeli Twój przedmiot jest w kategorii, w której dostępne są Przesyłki OLX, dodaj tę opcję do swojego ogłoszenia. Sprawdź, jak to zrobić, klikając tutaj.
# Krok 5. Kliknij przycisk Dodaj ogłoszenie lub Zobacz przed dodaniem.
# Krok 6. Jeżeli:
# Twoje ogłoszenie należy do płatnych kategorii — opłać zamówienie.
# chcesz, aby Twoje ogłoszenie było lepiej widoczne, wybierz jeden z dostępnych pakietów promowań. Więcej o pakietach znajdziesz tutaj.
# Twoje ogłoszenie nie należy do płatnych kategorii i nie chcesz skorzystać z pakietu promowania, kliknij przycisk Nie promuj. Jeśli przycisk nie jest widoczny — odznacz wybrane promowanie.
# Wszystkie zasady zamieszczania ogłoszeń znajdziesz tutaj.
#
#
# 4
# Jak usunąć konto?
# Usunięcie konta OLX spowoduje, że jego odzyskanie nie będzie już możliwe. Wszystkie Twoje dane zostaną skasowane.
# Krok 1. Zaloguj się na konto OLX.
# Krok 2. Jeśli korzystasz z:
# strony internetowej OLX — kliknij Twoje konto → Ustawienia → Zarządzanie kontem.
# aplikacji mobilnej OLX — kliknij Konto → Ustawienia.
# Krok 3. Kliknij przycisk Usuń konto → Wyślij e-mail.
# Krok 4. Przejdź na adres e-mail powiązany z kontem OLX i potwierdź chęć usunięcia konta.
# Zmiana e-mail/danych kontaktowych
# Zmiana adresu e-mail
# Zmiana danych kontaktowych
#
#
#
#
#
# Pytanie: {'question': 'Który punkt regulaminu OLX określa zasady zawieszenia lub blokady konta użytkownika w przypadku niepowodzenia weryfikacji danych?', 'document': 'a67ae3a0'}
# Oczekiwany dokument: ['Dodatkowe infrormacje przy rozwiażaniu umowy z użytkownikiem']
# Oczekiwany dokument: ['W celu zapewnienia zgodności Serwisu z wymaganiami obowiązującego prawa regulującego działalność platform internetowych, prawidłowego funkcjonowania Serwisu, ochrony i zapewnienia bezpieczeństwa korzystających z niego osób, Grupa OLX zastrzega sobie prawo do zwrócenia się do Użytkowników Biznesowych o przekazanie dodatkowych danych lub dokonania dodatkowej weryfikacji aktualności i prawdziwości danych podanych przez Użytkownika oraz żądania potwierdzenia przez Użytkownika jego tożsamości, informacji zawartych w Ogłoszeniu lub informacji związanych z dokonaną Transakcją w sposób wybrany przez Grupę OLX lub wynikający z obowiązujących przepisów. Jeśli weryfikacja danych lub tożsamości Użytkownika nie powiedzie się, Grupa OLX może zawiesić lub zablokować działanie Konta na zasadach określonych w punkcie 13 Regulaminu.']
#
# Znalezione dokumenty:
# 0
# W razie zmian w treści Ogłoszenia dokonanych przez Użytkownika po jego publikacji
# w Serwisie, Grupa OLX uprawniona do przeprowadzenia badania, czy zaktualizowana treść nie narusza Regulaminu oraz podjęcia odpowiednich działań, włączając w to usunięcie treści naruszających Regulamin lub przepisy obowiązującego prawa.
#
#
# 1
# Grupa OLX uprawniona jest do usunięcia Ogłoszenia lub zablokowania Konta jeśli zaistniało podejrzenie, że za pośrednictwem Ogłoszenia lub Konta mogło lub może dojść do działań zagrażających bezpieczeństwu innych Użytkowników w ramach Serwisu,
# jak również w przypadku, w którym Ogłoszenie negatywnie wpływa na dobre imię Grupy OLX lub w inny sposób szkodzi Grupie OLX.
#
#
# 2
# Każda osoba korzystająca z Serwisu ma możliwość zgłoszenia Grupie OLX treści bezprawnych lub sprzecznych z Regulaminem,
# rozpowszechnianych z wykorzystaniem funkcjonalności Serwisu, za pośrednictwem funkcjonalności “zgłoś naruszenie” dostępnej w ramach Ogłoszenia („Zgłoszenie nadużycia”). Zgłaszający powinien w miarę możliwości podać dane umożliwiające Grupie OLX dokonanie weryfikacji Zgłoszenia nadużycia, w tym w szczególności ID Ogłoszenia, wyjaśnienie powodów, dla których uznaje daną treść za bezprawną lub sprzeczną z Regulaminem oraz, jeżeli jest to wymagane w formularzu zgłoszenia, danych kontaktowych.
#
#
# 3
# Jak OLX przetwarza dane?
# Grupa OLX przetwarza dane osobowe Użytkowników, osób działających w imieniu Użytkowników oraz Gości zgodnie z postanowieniami Polityki Prywatności oraz Polityką dotyczącą Cookies i Podobnych Technologii.
#
#
# 4
# Grupa OLX podejmuje decyzje o blokadzie lub zawieszeniu treści lub Konta w oparciu o wewnętrzne polityki oraz procedury moderacyjne.
# Polityki oraz procedury moderacyjne przyjęte przez Grupę OLX opisują sposoby i środki identyfikacji treści lub działań Użytkowników, które są badane pod kątem
# naruszenia Regulaminu lub przepisów obowiązującego prawa. Głównym celem opracowanych polityk i procedur moderacyjnych jest zapewnienie bezpieczeństwa Użytkowników i zwalczanie wszelkich nadużyć.
#
#
#
#
#
# Pytanie: {'question': 'Jakie są konsekwencje nie wniesienia sprzeciwu przez użytkownika biznesowego w odpowiednim czasie?', 'document': '0e8ded0c'}
# Oczekiwany dokument: ['W przypadku uznania sprzeciwu, o którym mowa w pkt 13.7.']
# Oczekiwany dokument: ['za bezzasadny lub niewniesienia przez Użytkownika Biznesowego sprzeciwu w terminie 7 dni od pozyskania informacji określonej w punkcie 13.6.c.:\nzablokowana treść zostaje bezpowrotnie usunięta z Serwisu;\njeżeli dana treść była objęta jedną z Usług Odpłatnych, pobrana wcześniej opłata za emisję Ogłoszenia oraz związanych z danym Ogłoszeniem Usług Odpłatnych będzie zwracana na konto Użytkownika, w postaci punktów służących do ponownego skorzystania z usług Serwisu, w terminie 90 Dni liczonych od chwili usunięcia danego Ogłoszenia (jeden punkt odpowiada wartości 1 PLN). Na wniosek Użytkownika opłata może zostać zwrócona w formie pieniężnej, bezpośrednio na rachunek bankowy, z którego została dokonana płatność lub zgodnie z użytą metodą płatności.']
#
# Znalezione dokumenty:
# 0
# Umowa usługi Konta może zostać rozwiązana
# Umowa usługi Konta może zostać rozwiązana przez Użytkownika Biznesowego z zachowaniem reguł wskazanych w punkcie 3.10. w przypadku braku akceptacji zmian do Regulaminu, o których Użytkownik zostanie poinformowany zgodnie z punktem 18.1. b i c. W takim przypadku, w celu rozwiązania umowy w zakresie usługi Konta, Użytkownik Biznesowy powinien niezwłocznie, nie później niż w terminie 15 dni od ogłoszenia zmian powiadomić o tym Grupę OLX. Rozwiązanie przez Użytkownika w powyższym trybie umowy w zakresie usługi Konta odnosi skutek po upływie 15 dni od powiadomienia Użytkownika o zmianach Regulaminu, chyba że Użytkownik Biznesowy zrezygnuje z takiego powiadomienia albo złoży w tym zakresie stosowne oświadczenie lub podejmie wyraźne działanie w Serwisie potwierdzające akceptację takich warunków (np. publikacja nowego Ogłoszenia).
#
#
# 1
# Użytkownik zostanie poinformowany w razie dokonania blokady lub zawieszenia danej treści lub Konta,
# najpóźniej z chwilą, gdy blokada staje się skuteczna, w formie wiadomości e-mail, ze wskazaniem zablokowanej lub zawieszonej treści lub Konta, powodów decyzji o blokadzie lub zawieszeniu ze wskazaniem podstaw decyzji wynikających z treści Regulaminu.
# Użytkownik, który nie zgadza się z decyzją w przedmiocie zablokowania lub zawieszenia treści lub Konta, ma prawo do wniesienia skargi, zgodnie z postanowieniami punktu 15 Regulaminu. Dla uniknięcia wątpliwości, wniesienie lub niewniesienie skutecznego sprzeciwu w sytuacjach określonych punktem 13.6. lub 13.11. Regulaminu pozostaje bez wpływu na prawo Użytkownika do wniesienia reklamacji zgodnie z punktem 15 Regulaminu.
#
#
# 2
# Konsument
# Użytkownik będący osobą fizyczną, dokonujący w Serwisie czynności niezwiązanych bezpośrednio z jego działalnością gospodarczą lub zawodową.
#
#
# 3
# Czy mogę wystawić ocenę, jeśli zamówienie zostało anulowane?
# Nie, jest to możliwe tylko w przypadku, gdy zamówienie zostało dostarczone. Oznacza to, że sprzedającego można ocenić tylko wtedy, gdy kupujący otrzyma przedmiot, który od niego kupił z Przesyłką OLX.
# Nie wystarczy, że przedmiot dotrze do punktu odbioru — kupujący musi go odebrać, zanim będzie mógł wystawić ocenę.
#
#
# 4
# Czy mogę wystawić ocenę, jeśli nie odebrałem lub nie przyjąłem przedmiotu?
# Nie, jest to możliwe tylko w przypadku, gdy zamówienie zostało oznaczone jako dostarczone. Oznacza to, że sprzedającego można ocenić tylko wtedy, gdy kupujący otrzyma przedmiot, który od niego kupił z Przesyłką OLX.
# Nie wystarczy, że przedmiot dotrze do punktu odbioru — kupujący musi go odebrać, zanim będzie mógł wystawić ocenę.
#
#
#
#
#
# Pytanie: {'question': 'Co powinienem zrobić, jeśli nie jestem pewny, czy wpisuję prawidłowe hasło do mojego konta na OLX?', 'document': '469cc1f8'}
# Oczekiwany dokument: ['Nieprawidłowy login lub hasło']
# Oczekiwany dokument: ['Upewnij się, że poprawnie wpisujesz adres e-mail oraz hasło.\nZweryfikuj, czy klawisz Caps Lock jest wyłączony.\nSprawdź, czy urządzenie, z którego właśnie korzystasz, automatycznie nie podstawia starszych, zapisanych danych do logowania (jeśli wcześniej zmieniane było hasło). W tym przypadku pola, w których wpisujesz adres e-mail i hasło będą podświetlone oraz uzupełnione.\nWyczyścić pamięć podręczną, historię oraz pliki cookie z co najmniej miesiąca z przeglądarki, a dzięki temu nieaktualne dane nie będą już uzupełniane. Instrukcję jak to zrobić znajdziesz tutaj.\nJeśli nie masz pewności, czy wpisujesz prawidłowe hasło, skorzystaj z opcji zmiany hasła.']
#
# Znalezione dokumenty:
# 0
# Weryfikacja konta
# Nie mam SMS z kodem do weryfikacji konta
# Gdy będziesz dodawać pierwsze ogłoszenie na OLX, konieczne będzie zweryfikowanie Twojego konta za pomocą numeru telefonu.
# Krok 1. Zaloguj się na swoje konto OLX.
# Krok 2. Kliknij przycisk Dodaj ogłoszenie.
# Krok 3. Wpisz w wyznaczone pole swój numer telefonu — po chwili otrzymasz SMS z kodem weryfikacyjnym.
# Jeśli grafika jest nieczytelna, kliknij prawy przycisk myszy i wybierz "Otwórz grafikę w nowej karcie".
# Krok 4. Wpisz kod z wiadomości SMS i kliknij przycisk Weryfikuj.
# Nie mam SMS z kodem do weryfikacji konta
# Wiadomość SMS z kodem weryfikacyjnym zazwyczaj dociera w ciągu minuty. Może zdarzyć się, że wystąpi małe opóźnienie i poczekasz na kod do pół godziny. Jeżeli nie otrzymasz SMS w tym czasie, skontaktuj się ze swoim operatorem komórkowym i sprawdź, czy nie masz aktywnej blokady wiadomości premium oraz wiadomości reklamowych. Blokada tego typu może zablokować wiadomość SMS, którą do Ciebie wysłaliśmy. Nie poniesiesz kosztów za SMS, który otrzymasz od OLX.
#
#
# 1
# Nie znaleźliśmy konta z tym adresem e-mail. Spróbuj ponownie z innym adresem e-mail lub utwórz konto.
# Sprawdź, czy masz połączenie z internetem.
# Upewnij się, że poprawnie wpisujesz adres e-mail, na którym masz założone konto OLX.
# Zweryfikuj, czy klawisz Caps Lock jest wyłączony.
#
#
# 2
# Numer telefonu przypisany do innego konta OLX
# Jeżeli nie udało Ci się zweryfikować konta i widzisz poniższy komunikat, oznacza to, że wpisany numer został już użyty do weryfikacji innego konta OLX. Tym samym potwierdzenie obecnie zakładanego konta nie będzie możliwe.
# Jeśli grafika jest nieczytelna, kliknij prawy przycisk myszy i wybierz "Otwórz grafikę w nowej karcie".
# Jeden Użytkownik lub firma może korzystać wyłącznie z jednego konta. Jeśli masz już konto, to nie zweryfikujesz kolejnego. W przypadku gdy nie chcesz już korzystać z konta, które kiedyś zostało zweryfikowane Twoim numerem telefonu, możesz je usunąć. Dokładną instrukcję znajdziesz tutaj.​​​​​​​ Po usunięciu konta, Twój numer telefonu będzie mógł zostać użyty ponownie podczas zakładania nowego konta na OLX. Ze względów bezpieczeństwa do zwolnienia numeru dojdzie po 30 dniach od usunięcia poprzedniego konta.
#
#
# 3
# Jak usunąć konto?
# Usunięcie konta OLX spowoduje, że jego odzyskanie nie będzie już możliwe. Wszystkie Twoje dane zostaną skasowane.
# Krok 1. Zaloguj się na konto OLX.
# Krok 2. Jeśli korzystasz z:
# strony internetowej OLX — kliknij Twoje konto → Ustawienia → Zarządzanie kontem.
# aplikacji mobilnej OLX — kliknij Konto → Ustawienia.
# Krok 3. Kliknij przycisk Usuń konto → Wyślij e-mail.
# Krok 4. Przejdź na adres e-mail powiązany z kontem OLX i potwierdź chęć usunięcia konta.
# Zmiana e-mail/danych kontaktowych
# Zmiana adresu e-mail
# Zmiana danych kontaktowych
#
#
# 4
# Jak założyć konto?
# Krok 1. Załóż konto na OLX poprzez:
# stronę internetową OLX — kliknij Twoje konto → Załóż konto lub kliknij tutaj.
# aplikację mobilną OLX — kliknij Konto → Zaloguj się → Załóż konto.
# Jeśli grafika jest nieczytelna, kliknij prawy przycisk myszy i wybierz „Otwórz grafikę w nowej karcie".
# Krok 2. Wpisz swój adres e-mail.
# Krok 3. Wpisz hasło, które ma minimum 8 znaków, w tym przynajmniej jedną dużą i małą literę, jedną cyfrę oraz znak specjalny.
# Krok 4. Kliknij Zarejestruj się.
# Krok 5. Przejdź do skrzynki mailowej i w wiadomości od OLX kliknij przycisk Aktywuj konto.
# Jeśli nie masz linku aktywacyjnego — napisz do nas.
# Na jednym koncie OLX nie można sprzedawać przedmiotów prywatnych i przedmiotów w ramach prowadzenia firmy. Do każdego typu sprzedaży (prywatnie, jako firma) wymagane jest oddzielne konto.
# Konto na OLX możesz założyć za pomocą konta na Facebooku. Wystarczy, że klikniesz tutaj. Następnie wybierz przycisk Kontynuuj z Facebook i postępuj zgodnie z wyświetlanymi wskazówkami. W ten sposób utworzymy konto w OLX na adresie e-mail powiązanym z Twoim kontem Facebook. Przed wyborem „Kontynuuj z Facebookiem" sprawdź, czy jesteś zalogowany/zalogowana na danym urządzeniu do konta Facebook.
#
#
#
#
#
# Pytanie: {'question': "Do czego odnosi się termin 'kategoria' w serwisie OLX?", 'document': 'd728141a'}
# Oczekiwany dokument: ['Kategoria']
# Oczekiwany dokument: ['kategoria tematyczna (np. Motoryzacja czy Elektronika), do której przypisane jest Ogłoszenie. Kategoria może dzielić się na powiązane tematycznie podkategorie.']
#
# Znalezione dokumenty:
# 0
# Każda osoba korzystająca z Serwisu ma możliwość zgłoszenia Grupie OLX treści bezprawnych lub sprzecznych z Regulaminem,
# rozpowszechnianych z wykorzystaniem funkcjonalności Serwisu, za pośrednictwem funkcjonalności “zgłoś naruszenie” dostępnej w ramach Ogłoszenia („Zgłoszenie nadużycia”). Zgłaszający powinien w miarę możliwości podać dane umożliwiające Grupie OLX dokonanie weryfikacji Zgłoszenia nadużycia, w tym w szczególności ID Ogłoszenia, wyjaśnienie powodów, dla których uznaje daną treść za bezprawną lub sprzeczną z Regulaminem oraz, jeżeli jest to wymagane w formularzu zgłoszenia, danych kontaktowych.
#
#
# 1
# Kandydat
# Gość lub Użytkownik przeglądający Ogłoszenia w kategorii Praca lub korzystający z dedykowanych funkcjonalności określonych w Załączniku nr 1 “OLX Praca”.
#
#
# 2
# Czy mogę zmienić kategorię ogłoszenia?
# Po tym, jak zaakceptujemy Twoje ogłoszenie i będzie ono aktywne w OLX, nie będzie już możliwości zmiany jego kategorii.
# Jeśli uważasz, że Twoja oferta powinna znaleźć się w innej kategorii, zweryfikuj kategorię tutaj. Jeżeli nie masz pewności, którą kategorię wybrać lub chcesz dokonać jej zmiany, skontaktuj się z nami poprzez formularz kontaktowy.
#
#
# 3
# Jak OLX przetwarza dane?
# Grupa OLX przetwarza dane osobowe Użytkowników, osób działających w imieniu Użytkowników oraz Gości zgodnie z postanowieniami Polityki Prywatności oraz Polityką dotyczącą Cookies i Podobnych Technologii.
#
#
# 4
# Czy nowy System Ocen jest dostępny we wszystkich kategoriach?
# Oceny mogą wystawiać wyłącznie użytkownicy, którzy kupili przedmiot z Przesyłką OLX — i dopiero po jej otrzymaniu. Oznacza to, że oceny mogą być wystawiane wyłącznie po odebraniu przez Kupującego przedmiotu kupionego z Przesyłką OLX (kategorie, w których Przesyłka OLX jest dostępna). Gdy sprzedający otrzyma ocenę, jest ona wyświetlana na jego profilu i we wszystkich aktywnych ogłoszeniach (również tych, które nie mają włączonej Przesyłki OLX).
# Ogłoszenia w poniższych kategoriach nie będą wyświetlać oceny sprzedającego, ponieważ dotyczą usług lub przedmiotów, których nie można dostarczyć z Przesyłką OLX:
# Usługi
# Praca
# Nieruchomości
# Motoryzacja
# Wypożyczalnia
# Oznacza to, że:
# Jeśli sprzedający doda ogłoszenie w kategorii Usługi i ogłoszenie w kategorii Elektronika, jego ocena będzie wyświetlana tylko w ogłoszeniu w kategorii Elektronika.
# Jeżeli sprzedający dodał dwa ogłoszenia w kategorii Elektronika, ale tylko jedno z nich ma włączoną Przesyłkę OLX, jego ocena pojawi się w obu ogłoszeniach.
# System Ocen jest dostępny na stronie internetowej, stronie mobilnej i w wersji 4.95.1 (lub nowszej) aplikacji OLX na urządzenia z systemem iOS oraz w wersji 5.98.2 (lub nowszej) aplikacji OLX na urządzenia z systemem Android.

# %% [markdown]
# Several takeaways.
#
# Adjust ground truth. The results should be meaningful. Two small adjustments are needed:
# - We need to adjust the prompt to make sure that questions are formulated in a way that a user could really ask.
# - We should exclude the documents with term definitions from ground truth.
#
# Regarding retrieval:
# - We should check top 10 and let LLM rerank them.
# - We should check the performance of hybrid search.
# - We should check different embeddings.

# %% [markdown]
# ## Evaluation after adjusting ground truth
#
# `../data/ground-truth-data_2024_08_30.csv`

# %%
ground_truth_updated = pd.read_csv('../data/ground-truth-data_2024_08_30.csv')

# %%
ground_truth_updated = ground_truth_updated.to_dict(orient='records')

# %%
ground_truth_updated[0]
# Out:
# {'question': 'Jak mogę założyć konto przez stronę internetową OLX?',
#  'document': '2ddb5f16'}

# %%
res_updated = evaluate(ground_truth_updated, question_text_vector_knn)
# Out:
# 100%|██████████| 388/388 [00:29<00:00, 12.99it/s]

# %%
print(res_updated['hit_rate'])
print(res_updated['mrr'])
# Out:
# 0.6984536082474226
# 0.2290807560137462

# %% [markdown]
# The update did not significantly change the numbers. Those numbers are still quite low. Let's check how hybrid search performs.

# %%
def elastic_search_hybrid(
    query: str, 
    vector: list,
    index_name: str = "documents_olx_20240829_5014",
    field: str = 'question_text_vector', 
    section_to_exclude: str = "Definicje",
    k: int = 5,
    size: int = 10):
    
    # Exclusion Filter
    exclusion_filter = {
        "term": {"section": section_to_exclude}  # Term query for exclusion
    }
    
    knn_query = {
        "field": field,
        "query_vector": vector,
        "k": k,
        "num_candidates": 10000,
        "boost": 0.5,
        "filter": {
            "bool": {
                "must_not": [
                    exclusion_filter
                ]
            }
        }
    }

    keyword_query = {
        "bool": {
            "must": {
                "multi_match": {
                    "query": query,
                    "fields": ["question", "text", "section"],
                    "type": "best_fields",
                    "boost": 0.5,
                }
            },
            "filter": {
                "bool": {
                    "must_not": [
                        exclusion_filter
                    ]
                }
            }
        }
    }

    search_query = {
        "knn": knn_query,
        "query": keyword_query,
        "size": k,
        "_source": ["text", "section", "question", "course", "id"]
    }

    es_results = es_client.search(
        index=index_name,
        body=search_query
    )
    
    result_docs = []
    
    for hit in es_results['hits']['hits']:
        result_docs.append(hit['_source'])

    return result_docs

# %%
def question_hybrid(q, k=5):
    question = q['question']

    v_q = model.encode(question)

    return elastic_search_hybrid(question, v_q, field='question_text_vector', k=k)

def evaluate_hybrid(ground_truth, search_function):
    relevance_total = []
    results_total = []

    for q in tqdm(ground_truth):
        doc_id = q['document']
        results = search_function(q)
        relevance = [d['id'] == doc_id for d in results]
        relevance_total.append(relevance)
        results_total.append(results)

    return {
        'results_total': results_total,
        'relevance_total': relevance_total,
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total),
    }

# %%
res_hybrid = evaluate_hybrid(ground_truth_updated, question_hybrid)
# Out:
#   0%|          | 0/388 [00:00<?, ?it/s]
# 100%|██████████| 388/388 [00:25<00:00, 15.45it/s]

# %%
print(res_hybrid['hit_rate'])
print(res_hybrid['mrr'])
# Out:
# 0.7835051546391752
# 0.6411941580756015

# %% [markdown]
# Numbers went up, but still not good enough. Let's check the performance with reraanking.
#
# ## Reranking

# %%
# get 10 top results for each question
def question_hybrid_10(q):
    return question_hybrid(q, k=10)

# %%
res_hybrid_10 = evaluate_hybrid(ground_truth_updated, question_hybrid_10)
# Out:
# 100%|██████████| 388/388 [00:34<00:00, 11.31it/s]

# %%
# potential improvement:
print(res_hybrid_10['hit_rate'])
print(res_hybrid_10['mrr'])
# Out:
# 0.8608247422680413
# 0.6499468172148584

# %%
from openai import OpenAI
client = OpenAI()

# %%
prompt_template = """
Wybierz k {k} dokumentów, które najlepiej odpowiadają na poniższe pytanie:

Pytanie:

SEKCJA: {section}
PYTANIE: {question}
ODPOWIEDŹ: {text}

Dokumenty:
1. {doc1_question}
2. {doc2_question}
3. {doc3_question}
4. {doc4_question}
5. {doc5_question}
6. {doc6_question}
7. {doc7_question}
8. {doc8_question}
9. {doc9_question}
10. {doc10_question}

Odpowiedź powinna być w parsowalnym formacie JSON. Nie używaj bloków kodu:

["id_1", "id_2", ..., "id_k"]
""".strip()

# %%
# create a prompt for the question ground_truth_updated[0]
doc_id = ground_truth_updated[0]['document']
doc = [doc for doc in documents if doc['id'] == doc_id][0]
found_docs = question_hybrid(ground_truth_updated[0], k=10)
found_docs_questions = ['id: ' + doc['id'] + ". " + doc['question'] + " " + doc['text'] for doc in found_docs]

# %%
prompt = prompt_template.format(
    k=5,
    section=doc['section'],
    question=doc['question'],
    text=doc['text'],
    doc1_question=found_docs_questions[0],
    doc2_question=found_docs_questions[1],
    doc3_question=found_docs_questions[2],
    doc4_question=found_docs_questions[3],
    doc5_question=found_docs_questions[4],
    doc6_question=found_docs_questions[5],
    doc7_question=found_docs_questions[6],
    doc8_question=found_docs_questions[7],
    doc9_question=found_docs_questions[8],
    doc10_question=found_docs_questions[9],
)

# %%
response = client.chat.completions.create(
        model='gpt-4o',
        messages=[{"role": "user", "content": prompt}]
    )
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
 json.loads(response.choices[0].message.content)
# Out:
# ['2ddb5f16', '7c7a4947', '4dcf8b35', 'ff50559b', '37570bca']

# %%
# reranking is significant as we change the set of top 5 documents
[doc['id'] for doc in found_docs]
# Out:
# ['2ddb5f16',
#  '7c7a4947',
#  '4dcf8b35',
#  'aa9e24ac',
#  'ff50559b',
#  '6a293a6d',
#  'ea07084a',
#  'd30e6624',
#  '37570bca',
#  'e8caa77b']

# %%
import re 

def search_reranked_retrieval(q, k=10, max_doc_candidate_length=500):
    
    doc_id = q['document']
    doc = [doc for doc in documents if doc['id'] == doc_id][0]
    found_docs = question_hybrid(q, k=k)
    found_docs_questions = ['id: ' + doc['id'] + ". " + doc['question'] + " " + doc['text'] for doc in found_docs]

    prompt = prompt_template.format(
        k=5,
        section=doc['section'],
        question=doc['question'],
        text=doc['text'],
        doc1_question=found_docs_questions[0][:max_doc_candidate_length],
        doc2_question=found_docs_questions[1][:max_doc_candidate_length],
        doc3_question=found_docs_questions[2][:max_doc_candidate_length],
        doc4_question=found_docs_questions[3][:max_doc_candidate_length],
        doc5_question=found_docs_questions[4][:max_doc_candidate_length],
        doc6_question=found_docs_questions[5][:max_doc_candidate_length],
        doc7_question=found_docs_questions[6][:max_doc_candidate_length],
        doc8_question=found_docs_questions[7][:max_doc_candidate_length],
        doc9_question=found_docs_questions[8][:max_doc_candidate_length],
        doc10_question=found_docs_questions[9][:max_doc_candidate_length],
    )

    response = client.chat.completions.create(
        model='gpt-4o',
        messages=[{"role": "user", "content": prompt}]
    )

    json_response = response.choices[0].message.content
    
    if len(json_response) == 0:
        logger.info("Empty response from GPT-4o")
        return [doc['id'] for doc in found_docs[:5]]
    
    # quick preprocessing
    json_response_preprocessed = re.sub(r'```json', '', json_response)
    json_json_response_preprocessedresponse = re.sub(r'```', '', json_response_preprocessed)
    ids = json.loads(json_response)
    ids = [re.sub("id_", "", str(id)) for id in ids]
    ids = [re.sub("id:", "", str(id)) for id in ids]
    ids = [id.strip() for id in ids]
    ids = [id for id in ids if len(id) > 2]
    
    if len(ids) > 5:
        logger.warning("More than 5 ids returned from GPT-4o")
        return ids[:5]
    elif len(ids) < 5:
        logger.warning("Less than 5 ids returned from GPT-4o after preprocessing")
        logger.warning(json_response)
        tmp_ids = ids + [doc['id'] for doc in found_docs if doc['id'] not in ids]
        logger.info(f"Returning {tmp_ids[:5]}")
        return tmp_ids[:5]
    else:
        return ids

# %%
def evaluate_reranking(ground_truth, search_function):
    relevance_total = []
    result_total = []

    for q in tqdm(ground_truth):
        time.sleep(0.25)
        doc_id = q['document']
        try:
            results = search_function(q, k=10)
        except Exception as e:
            logging.error(e)
            # empty list of results of length 10
            results = ['' for _ in range(10)]
        relevance = [d == doc_id for d in results]
        relevance_total.append(relevance)
        result_total.append(results)

    return {
        'results_total': result_total,
        'relevance_total': relevance_total,
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total),
    }

# %%
res_reranking = evaluate_reranking(ground_truth_updated, search_reranked_retrieval)

# %%
res_reranking
# Out:
# {'results_total': [['2ddb5f16',
#    '4dcf8b35',
#    'aa9e24ac',
#    'ff50559b',
#    'd30e6624'],
#   ['e8caa77b', '4dcf8b35', '1106b1dc', '6c146627', 'aa9e24ac'],
#   ['33813c2c', '9e41cc6b', 'c95af011', '342037c3', 'b61f3a70'],
#   ['2ddb5f16', '4dcf8b35', '6c146627', '943a92e0', 'ff50559b'],
#   ['2ddb5f16', '943a92e0', '33813c2c', '1106b1dc', '469cc1f8'],
#   ['6c146627', '4dcf8b35', '78b8c86d', '2ddb5f16', '1106b1dc'],
#   ['943a92e0', '7e9de748', 'ce9623ca', '8e9de748', '9623ca'],
#   ['943a92e0', '78b8c86d', 'e3610c01', '7e9de748', 'd132587e'],
#   ['943a92e0', '469cc1f8', '9e41cc6b', '1106b1dc', 'ec79b98a'],
#   ['943a92e0', '78b8c86d', '2ddb5f16', '47ae523b', '7e9de748'],
#   ['9e41cc6b', '943a92e0', '33813c2c', 'd132587e', 'b8121ab6'],
#   ['9e41cc6b', '8ecf30ba', 'a67ae3a0', '469cc1f8', '4dcf8b35'],
#   ['9e41cc6b', '4dcf8b35', '943a92e0', '2ddb5f16', '78b8c86d'],
#   ['9e41cc6b', '4dcf8b35', '943a92e0', '2ddb5f16', '342037c3'],
#   ['9e41cc6b', '943a92e0', '0f5525bd', '342037c3', '33813c2c'],
#   ['7e9de748', '469cc1f8', '2ddb5f16', 'b61f3a70', '4dcf8b35'],
#   ['7e9de748', '469cc1f8', '2ddb5f16', '0b78fb57', '9e41cc6b'],
#   ['7e9de748', '469cc1f8', 'ea83195e', '9e41cc6b', '943a92e0'],
#   ['7e9de748', '2ddb5f16', '368caa05', 'd4e7a30b', '9e41cc6b'],
#   ['4dcf8b35', '314ee8cf', '9e41cc6b', 'c95af011', 'ce9623ca'],
#   ['469cc1f8', '0b78fb57', '9e41cc6b', '1106b1dc', 'c95af011'],
#   ['0b78fb57', 'ce9623ca', '9e41cc6b', '342037c3', 'eefc3ee3'],
#   ['469cc1f8', '4dcf8b35', 'e8caa77b', '7e9de748', '943a92e0'],
#   ['469cc1f8', '01f95cb6', '6c146627', 'ea07084a', '2f4756d7'],
#   ['469cc1f8', '9e41cc6b', '943a92e0', '342037c3', '38edb241'],
#   ['0b78fb57', '1106b1dc', 'e8caa77b', '38edb241', '01f95cb6'],
#   ['469cc1f8', '5e41cc6b', '342037c3', '8de237c3', '8d1d3a6b'],
#   ['ce9623ca', 'b61f3a70', '2e80fa3d', '4dcf8b35', '1106b1dc'],
#   ['0b78fb57', '469cc1f8', '7cc38cbf', '01f95cb6', '2ddb5f16'],
#   ['ce9623ca', '2ddb5f16', '4dcf8b35', '5e8caa77b', '6c146627'],
#   ['4dcf8b35', '01f95cb6', '1106b1dc', '2ddb5f16', 'c4479dd3'],
#   ['5dcf8b35', 'c95af011', 'e8caa77b', '469cc1f8', '1106b1dc'],
#   ['4dcf8b35', '1106b1dc', 'ea07084a', '6a293a6d', '2ddb5f16'],
#   ['4dcf8b35', '6c146627', 'e8caa77b', 'ec79b98a', 'c4479dd3'],
#   ['5dcf8b35', '0f5525bd', 'ec79b98a', '9e41cc6b', '2ddb5f16'],
#   ['e8caa77b', '4dcf8b35', 'ec79b98a', '2ddb5f16', '469cc1f8'],
#   ['e8caa77b', '4dcf8b35', '7e9de748', '342037c3', 'ec79b98a'],
#   ['e8caa77b', '4dcf8b35', '469cc1f8', '2ddb5f16', 'a74246e6'],
#   ['e8caa77b', '7e9de748', '4dcf8b35', '2ddb5f16', '469cc1f8'],
#   ['e8caa77b', '4dcf8b35', 'ec79b98a', '7e9de748', 'eefc3ee3'],
#   ['6c146627', '4dcf8b35', '7c7a4947', '5c920aad', 'ea07084a'],
#   ['6c146627', '38edb241', '342037c3', '1106b1dc', '7c7a4947'],
#   ['6c146627', 'ce9623ca', 'b8121ab6', 'e3610c01', '2e80fa3d'],
#   ['6c146627', '4dcf8b35', '342037c3', 'bdf287a5', '9e41cc6b'],
#   ['6c146627', '7c7a4947', '342037c3', 'bdf287a5', 'b8121ab6'],
#   ['342037c3', '943a92e0', '6c146627', '1106b1dc', 'bdf287a5'],
#   ['342037c3', '38edb241', '6c146627', '4dcf8b35', 'aa9e24ac'],
#   ['342037c3', '6a293a6d', 'c95af011', 'bdf287a5', '7c7a4947'],
#   ['342037c3', '943a92e0', '790a7ddb', 'a4863842', 'd728141a'],
#   ['342037c3', '1f9773b9', '790a7ddb', 'ce9623ca', '23b43d07'],
#   ['be4ae5c8', 'bdf287a5', 'd728141a', '342037c3', '7c7a4947'],
#   ['342037c3', 'bdf287a5', '7c7a4947', '314ee8cf', '790a7ddb'],
#   ['be4ae5c8', 'bdf287a5', '342037c3', '0f5525bd', '2f4756d7'],
#   ['342037c3', '790a7ddb', 'be4ae5c8', '1106b1dc', '7c7a4947'],
#   ['342037c3', 'bdf287a5', '7c7a4947', '790a7ddb', '943a92e0'],
#   ['7c7a4947', 'bdf287a5', '6c146627', '20bdbe32', '7293f181'],
#   ['7c7a4947', 'bdf287a5', '6c146627', '7293f181', '059738e5'],
#   ['7c7a4947', 'bdf287a5', '1106b1dc', '6c146627', '38edb241'],
#   ['7c7a4947', '342037c3', '1106b1dc', '6c146627', '790a7ddb'],
#   ['7c7a4947', '6c146627', '1106b1dc', '9cbf7c2b', '790a7ddb'],
#   ['790a7ddb', '342037c3', '1106b1dc', 'ec79b98a', 'eefc3ee3'],
#   ['1106b1dc', '342037c3', '6a293a6d', '01f95cb6', '0d5c9008'],
#   ['790a7ddb', '1106b1dc', '342037c3', '314ee8cf', '0b78fb57'],
#   ['790a7ddb', '1106b1dc', '943a92e0', '38edb241', 'd728141a'],
#   ['790a7ddb', '342037c3', '6a293a6d', '7c7a4947', 'bdf287a5'],
#   ['1106b1dc', '6a293a6d', '790a7ddb', 'bdf287a5', '7c7a4947'],
#   ['1106b1dc', '790a7ddb', '4dcf8b35', 'ec79b98a', '943a92e0'],
#   ['1106b1dc', '342037c3', '4dcf8b35', '6c146627', 'e8caa77b'],
#   ['1106b1dc', '790a7ddb', 'd728141a', '0b78fb57', '0d5c9008'],
#   ['1106b1dc', '368caa05', 'eefc3ee3', '469cc1f8', '790a7ddb'],
#   ['342037c3', '1106b1dc', '790a7ddb', '469cc1f8', 'bdf287a5'],
#   ['bdf287a5', 'be4ae5c8', '342037c3', 'e3610c01', '01f95cb6'],
#   ['bdf287a5', '7293f181', '33813c2c', '7c7a4947', '6c146627'],
#   ['bdf287a5', '7c7a4947', '342037c3', 'be4ae5c8', '6a293a6d'],
#   ['bdf287a5', 'be4ae5c8', '469cc1f8', '790a7ddb', '342037c3'],
#   ['2e80fa3d', 'bde8bc7c', 'd4e7a30b', '38edb241', '342037c3'],
#   ['2e80fa3d', 'eefc3ee3', '38edb241', 'c95af011', '342037c3'],
#   ['2e80fa3d', '314ee8cf', 'eefc3ee3', '78b8c86d', '37570bca'],
#   ['2e80fa3d', '1106b1dc', '342037c3', 'ce9623ca', '059738e5'],
#   ['2e80fa3d', '1106b1dc', '469cc1f8', 'c95af011', '368caa05'],
#   ['d132587e', '943a92e0', 'eefc3ee3', 'bde8bc7c', '2e80fa3d'],
#   ['d132587e', 'ec79b98a', 'b1f31cc0', '469cc1f8', '5e043cfd'],
#   ['d132587e', '9e41cc6b', '342037c3', '943a92e0', 'e8caa77b'],
#   ['d132587e', '2e80fa3d', '943a92e0', '953c5400', 'b8121ab6'],
#   ['d132587e', '943a92e0', 'ce9623ca', '15542325', '2e80fa3d'],
#   ['c95af011', '342037c3', 'ce9623ca', '1106b1dc', 'ad5b87dc'],
#   ['04ddfoe7', '243f677a', '10e7b2e5', '68b9302', '01f95cb6'],
#   ['c95af011', '342037c3', '2ddb5f16', '9e41cc6b', '78b8c86d'],
#   ['c95af011', '342037c3', '1106b1dc', '38edb241', '2e80fa3d'],
#   ['c95af011', '342037c3', 'eb62e045', 'e3610c01', '37570bca'],
#   ['38edb241', '342037c3', '6a293a6d', '01f95cb6', 'c95af011'],
#   ['38edb241', '314ee8cf', '78b8c86d', 'bde8bc7c', 'd4e7a30b'],
#   ['38edb241', '78b8c86d', 'bdf287a5', 'be4ae5c8', '6c146627'],
#   ['38edb241', 'ce9623ca', '469cc1f8', '01f95cb6', '0f5525bd'],
#   ['38edb241', '2ddb5f16', '1106b1dc', '943a92e0', '6c146627'],
#   ['e55a6ace', 'ad5b87dc', '953c5400', 'b7c49ccc', '60a68db3'],
#   ['d132587e', 'e55a6ace', '943a92e0', 'ad5b87dc', 'e3610c01'],
#   ['e55a6ace', 'eefc3ee3', '60a68db3', 'b6427a45', 'ad5b87dc'],
#   ['e55a6ace', 'ad5b87dc', '953c5400', 'b7c49ccc', '60a68db3'],
#   ['e55a6ace', 'd132587e', 'ec79b98a', '342037c3', 'c95af011'],
#   ['953c5400', 'b7c49ccc', '60a68db3', 'b6427a45', 'ad5b87dc'],
#   ['953c5400', 'b7c49ccc', 'e55a6ace', 'ad5b87dc', '60a68db3'],
#   ['953c5400', 'd132587e', 'b7c49ccc', 'b6427a45', '60a68db3'],
#   ['953c5400', 'ad5b87dc', 'e55a6ace', 'b7c49ccc', '60a68db3'],
#   ['953c5400', 'b7c49ccc', 'e55a6ace', 'ad5b87dc', '60a68db3'],
#   ['b7c49ccc', '4dcf8b35', '953c5400', '60a68db3', 'e55a6ace'],
#   ['b7c49ccc', '953c5400', '60a68db3', 'b6427a45', 'e55a6ace'],
#   ['342037c3', '2ddb5f16', '4dcf8b35', 'd132587e', 'eefc3ee3'],
#   ['b7c49ccc', '953c5400', 'e55a6ace', '60a68db3', 'b6427a45'],
#   ['b7c49ccc', '60a68db3', '953c5400', 'e55a6ace', 'b6427a45'],
#   ['b6427a45', 'ad5b87dc', 'e55a6ace', '953c5400', 'b7c49ccc'],
#   ['e55a6ace', '953c5400', 'b7c49ccc', '469cc1f8', 'd132587e'],
#   ['b6427a45', 'e55a6ace', '4dcf8b35', '51a23b03', '2f4756d7'],
#   ['b6427a45', '01f95cb6', '342037c3', '2e80fa3d', '37570bca'],
#   ['c95af011', '38edb241', 'ce9623ca', '368caa05', 'eefc3ee3'],
#   ['60a68db3', '342037c3', 'b6427a45', '953c5400', 'b7c49ccc'],
#   ['60a68db3', 'b6427a45', 'bdf287a5', 'be4ae5c8', 'd132587e'],
#   ['60a68db3', 'b7c49ccc', '953c5400', 'ad5b87dc', 'b6427a45'],
#   ['60a68db3', 'b6427a45', 'e55a6ace', 'd132587e', 'fbdcafed'],
#   ['60a68db3', 'b6427a45', 'e55a6ace', 'eefc3ee3', 'd132587e'],
#   ['ad5b87dc', 'e55a6ace', '953c5400', 'b7c49ccc', '60a68db3'],
#   ['ad5b87dc', 'e55a6ace', 'fbdcafed', '2ddb5f16', '469cc1f8'],
#   ['ad5b87dc', '342037c3', '953c5400', 'b7c49ccc', 'e55a6ace'],
#   ['ad5b87dc', 'e55a6ace', 'b7c49ccc', '953c5400', '60a68db3'],
#   ['ad5b87dc', 'e55a6ace', 'd132587e', 'eefc3ee3', '37570bca'],
#   ['7acd2acc', '342037c3', '1106b1dc', '15542325', '059738e5'],
#   ['1106b1dc', '342037c3', '7acd2acc', '15542325', '7293f181'],
#   ['7acd2acc', 'be4ae5c8', 'b7c49ccc', 'a4863842', '2f4756d7'],
#   ['314ee8cf', '0d5c9008', '2f4756d7', 'b8121ab6', 'e3610c01'],
#   ['314ee8cf', 'eefc3ee3', 'bdf287a5', '78b8c86d', '7c7a4947'],
#   ['314ee8cf', '01f95cb6', 'e3610c01', 'c4479dd3', '37570bca'],
#   ['e3610c01', 'c4479dd3', '2f4756d7', 'b8121ab6', '314ee8cf'],
#   ['314ee8cf', '78b8c86d', 'eefc3ee3', 'bde8bc7c', '9eb46939'],
#   ['eefc3ee3', 'bde8bc7c', 'd4e7a30b', '78b8c86d', 'f7c6bf38'],
#   ['314ee8cf', '37570bca', 'eefc3ee3', 'bde8bc7c', 'd4e7a30b'],
#   ['eefc3ee3', 'bde8bc7c', 'd4e7a30b', '78b8c86d', '314ee8cf'],
#   ['eefc3ee3', '314ee8cf', 'bde8bc7c', 'd4e7a30b', '37570bca'],
#   ['eefc3ee3', 'bde8bc7c', 'd4e7a30b', 'f151c2bb', '37570bca'],
#   ['f7c6bf38', '01f95cb6', '7c0b34d9', '04e38de9', 'e0865727'],
#   ['01f95cb6', '8ec79b98a', '37570bca', '78b8c86d', '0d5c9008'],
#   ['469cc1f8', '0eb46939', '2f4756d7', 'bdf287a5', 'b8121ab6'],
#   ['f7c6bf38', '01f95cb6', 'bdf287a5', 'eefc3ee3', 'd4e7a30b'],
#   ['01f95cb6', 'f7c6bf38', '37570bca', 'bdf287a5', 'b8121ab6'],
#   ['0eb46939', '314ee8cf', '37570bca', '5e043cfd', '2f4756d7'],
#   ['0eb46939', '314ee8cf', '5e043cfd', 'eefc3ee3', '37570bca'],
#   ['78b8c86d', 'd4e7a30b', 'bde8bc7c', '314ee8cf', 'f7c6bf38'],
#   ['78b8c86d', '314ee8cf', '0eb46939', '6d473600', '2cb4f50f'],
#   ['4a19c8d4', '78b8c86d', '314ee8cf', '0eb46939', 'bde8bc7c'],
#   ['5e043cfd', '37570bca', 'b1f31cc0', 'f151c2bb', '78b8c86d'],
#   ['b1f31cc0', 'f151c2bb', 'b8121ab6', '5e043cfd', '314ee8cf'],
#   ['5e043cfd', 'f151c2bb', '37570bca', '314ee8cf', 'b1f31cc0'],
#   ['5e043cfd', '37570bca', 'f151c2bb', '01f95cb6', 'e3610c01'],
#   ['', '', '', '', '', '', '', '', '', ''],
#   ['b1f31cc0', 'c4479dd3', '0d5c9008', '5e043cfd', '37570bca'],
#   ['b1f31cc0', 'c4479dd3', '0d5c9008', 'e3610c01', '5e043cfd'],
#   ['b1f31cc0', '37570bca', 'c4479dd3', '0d5c9008', 'e3610c01'],
#   ['b1f31cc0', '37570bca', 'c4479dd3', '0d5c9008', 'e3610c01'],
#   ['b1f31cc0', '37570bca', '0d5c9008', 'c4479dd3', 'e3610c01'],
#   ['ea83195e', 'ec79b98a', 'bdf287a5', 'b8121ab6', '78b8c86d'],
#   ['ea83195e', '01f95cb6', 'f7c6bf38', '2f4756d7', 'c4479dd3'],
#   ['ea83195e', '78b8c86d', '6c146627', 'f7c6bf38', '01f95cb6'],
#   ['ea83195e', '78b8c86d', 'ec79b98a', '314ee8cf', 'b8121ab6'],
#   ['2f4756d7', 'b1f31cc0', 'bde8bc7c', 'e3610c01', 'a74246e6'],
#   ['c4479dd3', '0d5c9008', 'eefc3ee3', 'b8121ab6', '01f95cb6'],
#   ['e3610c01', '0d5c9008', 'c4479dd3', '314ee8cf', '9f587812'],
#   ['e3610c01', '314ee8cf', 'c4479dd3', '2f4756d7', 'b8121ab6'],
#   ['e3610c01', 'c4479dd3', '0d5c9008', '2f4756d7', 'b8121ab6'],
#   ['e3610c01', 'c4479dd3', '0d5c9008', 'f7c6bf38', 'eefc3ee3'],
#   ['b8121ab6', 'e3610c01', 'd30e6624', 'f151c2bb', '01f95cb6'],
#   ['b8121ab6', '2f4756d7', 'e3610c01', '314ee8cf', '01f95cb6'],
#   ['b8121ab6', '2f4756d7', 'f151c2bb', 'eefc3ee3', '5e043cfd'],
#   ['b8121ab6', '2f4756d7', '01f95cb6', '314ee8cf', 'f151c2bb'],
#   ['b8121ab6', '2f4756d7', 'e3610c01', '314ee8cf', 'eefc3ee3'],
#   ['2f4756d7', 'b8121ab6', '314ee8cf', '01f95cb6', 'f151c2bb'],
#   ['2f4756d7', 'b8121ab6', '10f95cb6', 'c4479dd3', '37570bca'],
#   ['e3610c01', 'ec79b98a', '37570bca', '314ee8cf', '0d5c9008'],
#   ['2f4756d7', 'b8121ab6', '5e043cfd', 'ec79b98a', 'f151c2bb'],
#   ['2f4756d7', 'ec79b98a', 'b8121ab6', '5e043cfd', '78b8c86d'],
#   ['ec79b98a', 'b8121ab6', '2f4756d7', '0d5c9008', '10d5c9008'],
#   ['ec79b98a', '01f95cb6', '2f4756d7', 'e3610c01', '37570bca'],
#   ['ec79b98a', 'c4479dd3', 'b8121ab6', '2f4756d7', '0d5c9008'],
#   ['ec79b98a', '2f4756d7', 'b8121ab6', '78b8c86d', 'c4479dd3'],
#   ['0d5c9008', '314ee8cf', '37570bca', 'c4479dd3', 'fbdcafed'],
#   ['0d5c9008', 'c4479dd3', '01f95cb6', 'fbdcafed', '37570bca'],
#   ['0d5c9008', 'c4479dd3', 'e3610c01', '314ee8cf', '37570bca'],
#   ['0d5c9008', 'c4479dd3', '790a7ddb', '74123939', '1106b1dc'],
#   ['eefc3ee3', 'c4479dd3', '0d5c9008', 'e3610c01', '469cc1f8'],
#   ['0d5c9008', 'c4479dd3', 'e3610c01', '01f95cb6', 'eeffc3ee3'],
#   ['c4479dd3', 'fbdcafed', 'e3610c01', '01f95cb6', 'b8121ab6'],
#   ['c4479dd3', 'e3610c01', 'ec79b98a', '0d5c9008', '01f95cb6'],
#   ['c4479dd3', 'e3610c01', 'b8121ab6', '2f4756d7', '0d5c9008'],
#   ['c4479dd3', '0d5c9008', 'eefc3ee3', '01f95cb6', 'b8121ab6'],
#   ['c4479dd3', 'e3610c01', '37570bca', '78b8c86d', '2f4756d7'],
#   ['fbdcafed', '2f4756d7', '314ee8cf', '37570bca', 'eefc3ee3'],
#   ['fbdcafed', 'c4479dd3', 'e3610c01', '37570bca', '74123939'],
#   ['fbdcafed', 'f7c6bf38', 'bde8bc7c', '78b8c86d', 'd4e7a30b'],
#   ['fbdcafed', 'ec79b98a', '2ddb5f16', '78b8c86d', '943a92e0'],
#   ['37570bca', '01f95cb6', '2f4756d7', 'b8121ab6', 'ce9623ca'],
#   ['f151c2bb', 'e3610c01', '37570bca', '01f95cb6', '2f4756d7'],
#   ['e3610c01', '37570bca', '2f4756d7', 'b8121ab6', '78b8c86d'],
#   ['f151c2bb', '37570bca', 'e3610c01', 'eefc3ee3', 'c4479dd3'],
#   ['f151c2bb', 'e3610c01', 'c4479dd3', '01f95cb6', '0d5c9008'],
#   ['f151c2bb', 'e3610c01', 'b8121ab6', '37570bca', 'c4479dd3'],
#   ['01f95cb6', '4dcf8b35', '0d5c9008', 'f7c6bf38', 'bde8bc7c'],
#   ['01f95cb6', 'c4479dd3', '78b8c86d', '6a293a6d', '0d5c9008'],
#   ['01f95cb6', '78b8c86d', 'f7c6bf38', '0d5c9008', 'e3610c01'],
#   ['01f95cb6', 'f7c6bf38', '0eb46939', 'd4e7a30b', 'eefc3ee3'],
#   ['01f95cb6', 'bde8bc7c', 'c4479dd3', '2f4756d7', 'eefc3ee3'],
#   ['bde8bc7c', 'd4e7a30b', 'eefc3ee3', 'f7c6bf38', '78b8c86d'],
#   ['bde8bc7c', 'd4e7a30b', 'eefc3ee3', '78b8c86d', '8e043cfd'],
#   ['bde8bc7c', 'd4e7a30b', 'efc3ee3', '78b8c86d', '314ee8cf'],
#   ['bde8bc7c', 'd4e7a30b', '78b8c86d', 'eefc3ee3', 'b8121ab6'],
#   ['bde8bc7c', 'd4e7a30b', 'eefc3ee3', '314ee8cf', 'f7c6bf38'],
#   ['bde8bc7c', 'd4e7a30b', 'eefc3ee3', '78b8c86d', '01f95cb6'],
#   ['d4e7a30b', 'bde8bc7c', 'eefc3ee3', '78b8c86d', '01f95cb6'],
#   ['d4e7a30b', 'bde8bc7c', 'eefc3ee3', '78b8c86d', '5e043cfd'],
#   ['d4e7a30b', 'eefc3ee3', 'bde8bc7c', '314ee8cf', '78b8c86d'],
#   ['d4e7a30b', 'bde8bc7c', '78b8c86d', 'eefc3ee3', '314ee8cf'],
#   ['78b8c86d', '314ee8cf', 'd4e7a30b', '7bde8bc7c', '059738e5'],
#   ['78b8c86d', 'bde8bc7c', 'd4e7a30b', 'eefc3ee3', '314ee8cf'],
#   ['0eb46939', 'eefc3ee3', '78b8c86d', '2e80fa3d', '314ee8cf'],
#   ['78b8c86d', 'bde8bc7c', 'd4e7a30b', '314ee8cf', 'f7c6bf38'],
#   ['78b8c86d', '314ee8cf', '2f4756d7', '37570bca', '01f95cb6'],
#   ['5e043cfd', 'b1f31cc0', 'f151c2bb', '0eb46939', '314ee8cf'],
#   ['37570bca', 'f151c2bb', '5e043cfd', 'eefc3ee3', '314ee8cf'],
#   ['37570bca', 'e3610c01', 'c4479dd3', 'b1f31cc0', '01f95cb6'],
#   ['37570bca', '5e043cfd', 'eefc3ee3', '01f95cb6', '314ee8cf'],
#   ['37570bca', '4eb46939', 'f151c2bb', 'e3610c01', '5e043cfd'],
#   ['6a293a6d', '342037c3', '790a7ddb', '1106b1dc', '943a92e0'],
#   ['342037c3', '6a293a6d', 'ce9623ca', '314ee8cf', '1106b1dc'],
#   ['896d0dae', '342037c3', '790a7ddb', 'c95af011', '314ee8cf'],
#   ['896d0dae', '1106b1dc', '6a293a6d', '342037c3', '943a92e0'],
#   ['790a7ddb', '342037c3', 'fc0dd85c', 'ad5b87dc', 'ff50559b'],
#   ['aa9e24ac', '2e80fa3d', '6a293a6d', '84d8b35f', '01f95cb6'],
#   ['aa9e24ac', '2ddb5f16', '5c920aad', 'ec79b98a', '7bfb63ba'],
#   ['aa9e24ac', '4dcf8b35', '9e41cc6b', '0f5525bd', 'd30e6624'],
#   ['33813c2c', '059738e5', '5c920aad', 'aa9e24ac', 'a74246e6'],
#   ['aa9e24ac', '0f5525bd', '20bdbe32', 'd30e6624', 'b61f3a70'],
#   ['5c920aad', 'aa9e24ac', '2ddb5f16', '9e41cc6b', '8d335987'],
#   ['9e41cc6b', '943a92e0', '368caa05', '4dcf8b35', 'ff50559b'],
#   ['84d8b35f', '1f9773b9', '0d8df57a', 'ea07084a', '2ddb5f16'],
#   ['84d8b35f', '1f9773b9', '9e41cc6b', '5c920aad', 'aa9e24ac'],
#   ['84d8b35f', '1f9773b9', '0d5c9008', '2ddb5f16', 'ff50559b'],
#   ['d30e6624', 'b61f3a70', 'ff50559b', '4dcf8b35', '2ddb5f16'],
#   ['d30e6624', '4dcf8b35', 'ff50559b', 'aa9e24ac', '2ddb5f16'],
#   ['d30e6624', '9e41cc6b', '368caa05', 'b61f3a70', '4dcf8b35'],
#   ['d30e6624', '368caa05', 'aa9e24ac', '943a92e0', '2ddb5f16'],
#   ['d30e6624', 'c4479dd3', '469cc1f8', 'a67ae3a0', 'c95af011'],
#   ['a74246e6', '4dcf8b35', '6c146627', '8a2ddb5f16', 'ff50559b'],
#   ['2ddb5f16', '33813c2c', '0f5525bd', '943a92e0', '78b8c86d'],
#   ['33813c2c', '2ddb5f16', 'a74246e6', '943a92e0', '4ddb5f16'],
#   ['33813c2c', 'a74246e6', 'aa9e24ac', 'b61f3a70', '7293f181'],
#   ['f018251f', '33813c2c', 'aa9e24ac', '7c7a4947', 'd30e6624'],
#   ['ea07084a', '6a293a6d', '6c146627', 'a74246e6', '5c920aad'],
#   ['ea07084a', '5c920aad', 'a67ae3a0', '1f9773b9', '84d8b35f'],
#   ['ea07084a', '5c920aad', 'a74246e6', '20bdbe32', '059738e5'],
#   ['ff50559b', 'bf244995', 'a67ae3a0', '4dcf8b35', '9c11090d'],
#   ['ea07084a', 'aa9e24ac', '469cc1f8', '653d264c', 'bf244995'],
#   ['33813c2c', '0f5525bd', 'a74246e6', '6a293a6d', 'aa9e24ac'],
#   ['33813c2c', '0f5525bd', '2e80fa3d', '943a92e0', 'b61f3a70'],
#   ['33813c2c', '9e41cc6b', '943a92e0', 'b61f3a70', '469cc1f8'],
#   ['33813c2c', '01f95cb6', 'e8caa77b', '9e41cc6b', '6a293a6d'],
#   ['33813c2c', '2ddb5f16', 'f018251f', '059738e5', '9e41cc6b'],
#   ['a74246e6', 'b61f3a70', 'c4479dd3', '469cc1f8', '8c10cf59'],
#   ['a67ae3a0', 'bf80eb5e', '059738e5', '78b8c86d', '01f95cb6'],
#   ['ea07084a', '20bdbe32', '6a293a6d', 'a74246e6', '342037c3'],
#   ['5a74246e6', 'd30e6624', '6c146627', '4dcf8b35', '3469cc1f8'],
#   ['a74246e6', 'b61f3a70', '33813c2c', '0b78fb57', 'a67ae3a0'],
#   ['1f9773b9', '84d8b35f', 'aa9e24ac', 'c950ef55', '059738e5'],
#   ['1f9773b9', '84d8b35f', '0d8df57a', 'ea07084a', '790a7ddb'],
#   ['059738e5', '78b8c86d', '8c4b3f8b', 'aa9e24ac', '15542325'],
#   ['84d8b35f', '1f9773b9', '47ae523b', '7e9de748', '2ddb5f16'],
#   ['1f9773b9', '84d8b35f', 'b61f3a70', 'ea07084a', '368caa05'],
#   ['bf244995', '2e80fa3d', '943a92e0', '7a9a98fb', 'd30e6624'],
#   ['469cc1f8', 'b1f31cc0', '6a293a6d', '9e41cc6b', '368caa05'],
#   ['bf244995', 'a74246e6', 'd30e6624', '9e41cc6b', '4dcf8b35'],
#   ['4dcf8b35', 'a74246e6', '469cc1f8', 'f018251f', '0b78fb57'],
#   ['bf244995', '6c146627', 'd30e6624', 'a67ae3a0', 'ea07084a'],
#   ['0f5525bd', '33813c2c', '47ae523b', '6a293a6d', '2b0d81ee'],
#   ['4dcf8b35', '368caa05', '1106b1dc', '790a7ddb', '38edb241'],
#   ['0f5525bd', '33813c2c', '4dcf8b35', 'aa9e24ac', '7eb4ae80'],
#   ['0f5525bd', '4dcf8b35', '943a92e0', 'ce9623ca', '1106b1dc'],
#   ['0f5525bd', '2b0d81ee', '33813c2c', '9e41cc6b', 'aa9e24ac'],
#   ['2ddb5f16', '6a293a6d', '84d8b35f', '4dcf8b35', '368caa05'],
#   ['368caa05', 'd30e6624', '4dcf8b35', '2ddb5f16', '1106b1dc'],
#   ['4dcf8b35', 'ff50559b', '2ddb5f16', '0b78fb57', 'ea07084a'],
#   ['9e41cc6b', '7e9de748', '4dcf8b35', '2ddb5f16', '01f95cb6'],
#   ['0f5525bd', '2b0d81ee', '8f5525bd', 'd41cc6b6', '0f5525bd'],
#   ['a67ae3a0', '0f5525bd', 'b61f3a70', '2b0d81ee', '47ae523b'],
#   ['0f5525bd', 'b61f3a70', 'a67ae3a0', '368caa05', 'ea07084a'],
#   ['b61f3a70', '0f5525bd', 'a67ae3a0', '1f9773b9', '20bdbe32'],
#   ['a67ae3a0', '0f5525bd', 'b61f3a70', '368caa05', '4dcf8b35'],
#   ['b61f3a70', '2b0d81ee', 'a67ae3a0', '0f5525bd', '33813c2c'],
#   ['47ae523b', '2b0d81ee', 'b61f3a70', '33813c2c', '0f5525bd'],
#   ['47ae523b', 'b61f3a70', '0f5525bd', '2b0d81ee', '7f365966'],
#   ['47ae523b', '0f5525bd', '2b0d81ee', 'b61f3a70', '33813c2c'],
#   ['47ae523b', 'b61f3a70', '2b0d81ee', '33813c2c', '4dcf8b35'],
#   ['47ae523b', '0f5525bd', '33813c2c', '2b0d81ee', 'b61f3a70'],
#   ['2b0d81ee', '0f5525bd', 'b61f3a70', '33813c2c', 'd30e6624'],
#   ['2b0d81ee', '5c920aad', '368caa05', '1106b1dc', '7293f181'],
#   ['2b0d81ee', '0f5525bd', '15542325', 'b61f3a70', '653d264c'],
#   ['2b0d81ee', '0f5525bd', 'b61f3a70', '47ae523b', '33813c2c'],
#   ['2b0d81ee', '9e41cc6b', 'd30e6624', '6a293a6d', '7293f181'],
#   ['059738e5', 'aa9e24ac', '0d8df57a', '469cc1f8', '7c7a4947'],
#   ['059738e5', '0d8df57a', 'aa9e24ac', '7c7a4947', '9f5525bd'],
#   ['059738e5', '0d8df57a', 'aa9e24ac', '5c920aad', '1f9773b9'],
#   ['059738e5', '0d8df57a', '7c7a4947', 'aa9e24ac', '5c920aad'],
#   ['2ddb5f16', 'd30e6624', '9e41cc6b', '7e9de748', '943a92e0'],
#   ['059738e5', '0d8df57a', 'aa9e24ac', '2ddb5f16', '78b8c86d'],
#   ['0d8df57a', '059738e5', 'aa9e24ac', '368caa05', 'bf80eb5e'],
#   ['059738e5', '0d8df57a', '5c920aad', 'aa9e24ac', 'd30e6624'],
#   ['059738e5', '0d8df57a', 'aa9e24ac', '7e9de748', '2ddb5f16'],
#   ['059738e5', '0d8df57a', 'aa9e24ac', '7c7a4947', '6f51a8e3'],
#   ['5c920aad', '7c146627', '2b0d81ee', 'aa9e24ac', '059738e5'],
#   ['5c920aad', '0d8df57a', 'aa9e24ac', 'bf244995', 'd4e7a30b'],
#   ['059738e5', '6c146627', '5e74246e6', 'ea07084a', 'aa9e24ac'],
#   ['5c920aad', '2b0d81ee', '059738e5', 'aa9e24ac', '7d8df57a'],
#   ['5c920aad', 'a67ae3a0', '6c146627', '4dcf8b35', '47ae523b'],
#   ['bf80eb5e', '7293f181', '653d264c', '15542325', 'd261a76e'],
#   ['bf80eb5e', '51a23b03', '7293f181', 'ea07084a', '2ddb5f16'],
#   ['bf80eb5e', 'fc0dd85c', 'd30e6624', '6a293a6d', '368caa05'],
#   ['2ddb5f16', '0d5c9008', 'c4479dd3', '7acd2acc', 'e3610c01'],
#   ['d261a76e', 'ff50559b', '943a92e0', '7e9de748', '2f4756d7'],
#   ['fc0dd85c', 'bf80eb5e', '74123939', '368caa05', 'd261a76e'],
#   ['fc0dd85c', 'bf80eb5e', '7293f181', '74123939', '6a293a6d'],
#   ['fc0dd85c', 'a74246e6', '368caa05', 'b61f3a70', '7293f181'],
#   ['bf80eb5e', 'fc0dd85c', '7bfb63ba', 'd261a76e', '20bdbe32'],
#   ['fc0dd85c', 'bf80eb5e', '15542325', '7293f181', '74123939'],
#   ['7bfb63ba', '653d264c', '74123939', '368caa05', 'f1be8bd4'],
#   ['7bfb63ba', '7293f181', '653d264c', 'bf80eb5e', '059738e5'],
#   ['7bfb63ba', 'f1be8bd4', '15542325', 'd261a76e', '6a293a6d'],
#   ['7bfb63ba', '7e9de748', '6f80eb5e', 'f1be8bd4', '15542325'],
#   ['7293f181', '51a23b03', '20bdbe32', '059738e5', '0e8ded0c'],
#   ['7293f181', '15542325', '368caa05', '51a23b03', '790a7ddb'],
#   ['01f95cb6', '20bdbe32', 'bdf287a5', '5c920aad', '059738e5'],
#   ['51a23b03', '20bdbe32', '15542325', '6a293a6d', '7293f181'],
#   ['7293f181', '1106b1dc', '943a92e0', '4dcf8b35', '9e41cc6b'],
#   ['7293f181', 'f1be8bd4', '74123939', '653d264c', '15542325'],
#   ['20bdbe32', '51a23b03', '643d264c', '74123939', '6f1be8bd4'],
#   ['368caa05', '20bdbe32', '9e41cc6b', '7acd2acc', '78b8c86d'],
#   ['20bdbe32', '368caa05', '653d264c', 'bdf287a5', 'a67ae3a0'],
#   ['20bdbe32', '7bfb63ba', '7293f181', '5c920aad', 'aa9e24ac'],
#   ['20bdbe32', 'bf80eb5e', 'a67ae3a0', 'a74246e6', '368caa05'],
#   ['15542325', '7293f181', '20bdbe32', '6a293a6d', '368caa05'],
#   ['15542325', '7293f181', '01f95cb6', 'd728141a', 'bdf287a5'],
#   ['20bdbe32', '15542325', '51a23b03', '7293f181', '2b0d81ee'],
#   ['15542325', 'bf80eb5e', '51a23b03', '7293f181', '13a60d5b'],
#   ['15542325', 'd261a76e', '653d264c', '51a23b03', '7293f181'],
#   ['d261a76e', '15542325', '51a23b03', '5c920aad', '7293f181'],
#   ['51a23b03', '6a293a6d', '01f95cb6', 'bdf287a5', '1106b1dc'],
#   ['51a23b03', '15542325', '368caa05', 'd261a76e', 'bf80eb5e'],
#   ['15542325', '51a23b03', '78b8c86d', '314ee8cf', '790a7ddb'],
#   ['d261a76e', '7bfb63ba', '15542325', 'a74246e6', '6a293a6d'],
#   ['0e8ded0c', '368caa05', 'c4479dd3', 'b1f31cc0', '790a7ddb'],
#   ['0e8ded0c', '51a23b03', '790a7ddb', '33813c2c', '47ae523b'],
#   ['51a23b03', '0e8ded0c', '7293f181', '2b0d81ee', 'd4e7a30b'],
#   ['0f5525bd', '2b0d81ee', '01f95cb6', '0d5c9008', 'c4479dd3'],
#   ['0e8ded0c', '51a23b03', '78b8c86d', '790a7ddb', 'ea83195e'],
#   ['6a293a6d', 'd728141a', 'aa9e24ac', 'bdf287a5', '9e41cc6b'],
#   ['6a293a6d', '368caa05', '15542325', 'a67ae3a0', '51a23b03'],
#   ['6a293a6d', 'd261a76e', 'a74246e6', '0f5525bd', '1f9773b9'],
#   ['6a293a6d', 'eefc3ee3', '943a92e0', '84d8b35f', '2b0d81ee'],
#   ['6a293a6d', 'a67ae3a0', 'bdf287a5', '84d8b35f', '790a7ddb'],
#   ['c95af011', 'a67ae3a0', '368caa05', 'd261a76e', '01f95cb6'],
#   ['368caa05', '74123939', '15542325', 'bf80eb5e', '0e8ded0c'],
#   ['368caa05', '653d264c', 'a67ae3a0', '7293f181', 'aa9e24ac'],
#   ['368caa05', 'd261a76e', '0f5525bd', '0eb46939', '9e41cc6b'],
#   ['368caa05', 'd30e6624', '33813c2c', '4dcf8b35', '0b78fb57'],
#   ['368caa05', '7b61f3a70', '10f1be8bd4', 'c4479dd3', 'eefc3ee3'],
#   ['368caa05', '9e41cc6b', '4dcf8b35', '7e9de748', '01f95cb6'],
#   ['6a293a6d', '943a92e0', '1106b1dc', '314ee8cf', '790a7ddb'],
#   ['a74246e6', '15542325', '4dcf8b35', 'd261a76e', '0f5525bd'],
#   ['b61f3a70', '4dcf8b35', '01f95cb6', '78b8c86d', '9e41cc6b'],
#   ['653d264c', 'd261a76e', '15542325', '74123939', '5f1be8bd4'],
#   ['653d264c', '74123939', 'f1be8bd4', '6a293a6d', '15542325'],
#   ['653d264c', 'f1be8bd4', '74123939', 'c95af011', '5c920aad'],
#   ['653d264c', '368caa05', '7293f181', 'd261a76e', '74123939'],
#   ['653d264c', '74123939', '368caa05', 'f1be8bd4', 'd261a76e'],
#   ['74123939', '20bdbe32', 'f018251f', '15542325', '01f95cb6'],
#   ['f1be8bd4', '7293f181', '20bdbe32', '15542325', '7bfb63ba'],
#   ['653d264c', '74123939', '368caa05', '8a293a6d', '01f95cb6'],
#   ['f1be8bd4', '7293f181', 'fc0dd85c', '368caa05', 'aa9e24ac'],
#   ['f1be8bd4', '74123939', '653d264c', '6a293a6d', '8ff50559b'],
#   ['74123939', '7293f181', '01f95cb6', 'c4479dd3', 'aa9e24ac'],
#   ['74123939', '653d264c', 'f1be8bd4', '15542325', '6a293a6d'],
#   ['74123939', '1fbe8bd4', '653d264c', '15542325', '7293f181'],
#   ['7293f181', 'f1be8bd4', '653d264c', '74123939', 'bf80eb5e'],
#   ['74123939', '653d264c', '368caa05', 'f1be8bd4', '01f95cb6']],
#  'relevance_total': [[True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, True, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, True],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, True],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, True, False, False],
#   [False, False, False, True, False],
#   [True, False, False, False, False],
#   [False, False, False, True, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False, False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, True, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, True, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, True, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [False, True, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, True],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, True, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, True, False],
#   [True, False, False, False, False]],
#  'hit_rate': 0.8298969072164949,
#  'mrr': 0.7781786941580756}

# %%
print(res_reranking['hit_rate'])
print(res_reranking['mrr'])
# Out:
# 0.8298969072164949
# 0.7781786941580756

# %% [markdown]
# This is significantly better. Let's check few examples where the model failed to retrieve the correct document.

# %%
failed_retrieval = [i for i, r in enumerate(res_reranking['relevance_total']) if not any(r)]

# %%
for i in random.sample(failed_retrieval, 5):
    print("Pytanie:", ground_truth_updated[i])
    expected_doc_id = ground_truth_updated[i]['document']
    print("Oczekiwany dokument:", [doc['question'] for doc in documents if doc['id'] == expected_doc_id])
    print("Oczekiwany dokument:", [doc['text'] for doc in documents if doc['id'] == expected_doc_id])
    
    returned_docs = res_reranking['results_total'][i]
    print("\nZnalezione dokumenty:")
    for j, doc_id in enumerate(returned_docs):
        print(j)
        doc = [doc for doc in documents if doc['id'] == doc_id][0]
        print(doc['question'])
        print(doc['text'])
        print("\n")
    
    print("\n\n")
# Out:
# Pytanie: {'question': 'Do jakiej kategorii wstawić ogłoszenie o sprzedaży wózka dziecięcego?', 'document': 'be4ae5c8'}
# Oczekiwany dokument: ['Którą kategorię wybrać?']
# Oczekiwany dokument: ['Sprawdź, w której kategorii powinien znaleźć się Twój przedmiot lub usługa. Wybierz kategorię:\nAntyki i Kolekcje\nDla Dzieci\nDla Firm\nDla Ukrainy\nDom i Ogród\nElektronika\nModa\nMotoryzacja\nMuzyka i Edukacja\nNieruchomości\nNoclegi\nPraca\nRolnictwo\nSport i Hobby\nWypożyczalnia\nUsługi\nZdrowie i Uroda\nZwierzęta']
#
# Znalezione dokumenty:
# 0
# Jak dodać ogłoszenie?
# Aby dodać ogłoszenie:
# Krok 1. Zaloguj się do swojego konta w OLX.
# Krok 2. Jeśli korzystasz z:
# strony internetowej OLX — kliknij przycisk Dodaj ogłoszenie — znajdziesz go w prawym, górnym rogu.
# aplikacji mobilnej OLX — kliknij przycisk Dodaj — znajdziesz go na dole ekranu.
# Dodaj_ogłoszenie.png
# Jeśli grafika jest nieczytelna, kliknij prawy przycisk myszy i wybierz „Otwórz grafikę w nowej karcie".
# Krok 3. Uzupełnij szczegóły ogłoszenia.
# Tytuł
# Wpisz tytuł ogłoszenia. Po słowach z tytułu ogłoszenia Użytkownicy mogą wyszukać Twoją ofertę. Pamiętaj, aby nie pisać tylko wielkimi literami.
# Kategoria
# Wybierz kategorię sprzedawanego przedmiotu samodzielnie na podstawie naszych podpowiedzi lub skorzystaj z dostępnej listy. Jeżeli chcesz się upewnić, że wybierasz odpowiednią kategorię, zajrzyj tutaj.
# Cena
# Podaj cenę. Powinna ona odzwierciedlać wartość przedmiotu. Możesz również wybrać opcję Za darmo lub Zamienię. Pamiętaj, aby w ogłoszeniu wpisać rzeczywistą, oczekiwaną kwotę całkowitą brutto (w polskiej walucie).
# Opcje „Za darmo” oraz „Zamienię” nie są dostępne w kategorii Motoryzacja, w części podkategorii Nieruchomości oraz w kategorii Rolnictwo: Ciągniki, Maszyny rolnicze, Przyczepy, Części do maszyn rolniczych, Opony rolnicze.
# W niektórych kategoriach podanie ceny nie jest możliwe — na przykład w kategoriach usługowych. Możesz wtedy zamieścić cenę usługi w treści oferty.
# Typ ogłoszenia
# Typ ogłoszenia (osoba prywatna/firma) zostanie przypisany automatycznie po złożeniu deklaracji, w jaki sposób sprzedajesz na OLX. Pamiętaj, że deklaracja jest przypisana do wszystkich Twoich ogłoszeń i jej zmiana jest niemożliwa.
# Opis
# W tym miejscu podaj wszystkie szczegóły dotyczące przedmiotu/usługi. Zadbaj o szczegółowy i przejrzysty opis. W przypadku sprzedaży przedmiotu opisz stan, użyteczność, podaj parametry oraz ewentualne wady.
# Zdjęcia
# Kliknij Dodaj zdjęcie lub kliknij symbol aparatu, aby dodać zdjęcia, które najlepiej odzwierciedlą Twój przedmiot. Zadbaj o dobrą jakość zdjęć (maksymalna wielkość to 5 MB (format 4:3) lub 1500 x 1205 pikseli. Akceptowane formaty to: jpg, jpeg, png).
# Jeżeli chcesz się dowiedzieć, jak powinny wyglądać dobre zdjęcia, zapraszamy do naszego poradnika Jak zrobić atrakcyjne zdjęcia?
# Przypominamy także, że zgodnie z naszymi Zasadami, dodane zdjęcia:
# → nie mogą pochodzić z Internetu (łamią wtedy bowiem prawa autorskie),
# → powinny przedstawiać wyłącznie oferowany przedmiot,
# → nie powinny zawierać danych kontaktowych np. numeru telefonu.
# W kategorii Praca dodanie zdjęcia nie będzie możliwe.
# Dane kontaktowe i lokalizacja
# → Wybierz miejscowość i dzielnicę, w której można obejrzeć Twój przedmiot lub w której wykonujesz usługę. Użytkownicy nie będę widzieć Twojego dokładnego adresu.
# → Wpisz osobę kontaktową — będzie ona pojawiać się w każdym ogłoszeniu, które dodasz.
# → Wskazany adres e-mail jest powiązany z kontem.
# → Numer telefonu — Użytkownicy będą kontaktować się z Tobą poprzez wiadomości OLX. Jeżeli chcesz, aby kontaktowali się z Tobą również telefonicznie — podaj swój numer telefonu. Aby podać więcej niż jeden numer telefonu — rozdziel je przecinkiem i spacją, np. „601234XXX, 601234YYY".
# Dane takie jak: adres e-mail, miejscowość, numer telefonu oraz imię osoby kontaktowej możesz uzupełnić / zmienić w zakładce Ustawienia / Dane kontaktowe. Będą one widoczne podczas dodawania kolejnych ogłoszeń.
# Dodatkowe parametry
# W części kategorii konieczne będzie dodanie dodatkowych parametrów. W kategorii Moda — rozmiar ubrania, w kategorii Praca — rodzaj umowy, a w kategorii Motoryzacja/Części samochodowe — parametry oferowanej części. Wypełnij pola oznaczone gwiazdką.
# Krok 4. Jeżeli Twój przedmiot jest w kategorii, w której dostępne są Przesyłki OLX, dodaj tę opcję do swojego ogłoszenia. Sprawdź, jak to zrobić, klikając tutaj.
# Krok 5. Kliknij przycisk Dodaj ogłoszenie lub Zobacz przed dodaniem.
# Krok 6. Jeżeli:
# Twoje ogłoszenie należy do płatnych kategorii — opłać zamówienie.
# chcesz, aby Twoje ogłoszenie było lepiej widoczne, wybierz jeden z dostępnych pakietów promowań. Więcej o pakietach znajdziesz tutaj.
# Twoje ogłoszenie nie należy do płatnych kategorii i nie chcesz skorzystać z pakietu promowania, kliknij przycisk Nie promuj. Jeśli przycisk nie jest widoczny — odznacz wybrane promowanie.
# Wszystkie zasady zamieszczania ogłoszeń znajdziesz tutaj.
#
#
# 1
# Czy mogę zmienić kategorię ogłoszenia?
# Po tym, jak zaakceptujemy Twoje ogłoszenie i będzie ono aktywne w OLX, nie będzie już możliwości zmiany jego kategorii.
# Jeśli uważasz, że Twoja oferta powinna znaleźć się w innej kategorii, zweryfikuj kategorię tutaj. Jeżeli nie masz pewności, którą kategorię wybrać lub chcesz dokonać jej zmiany, skontaktuj się z nami poprzez formularz kontaktowy.
#
#
# 2
# Jak edytować ogłoszenie?
# W każdej chwili możesz edytować prawie wszystkie parametry ogłoszenia. Nie możesz jednak zmienić:
# kategorii,
# typu sprzedającego (prywatnie/jako przedsiębiorca),
# roku produkcji, modelu, pojemności silnika (ogłoszenia dotyczące pojazdów),
# powierzchni (ogłoszenia dotyczące nieruchomości),
# lokalizacji w kategorii Nieruchomości (mieszkania / sprzedaż oraz mieszkania / wynajem). W kategorii Praca lokalizację można zmienić wyłącznie do 4 h od dodania ogłoszenia.
# Aby edytować ogłoszenie:
# Krok 1. Zaloguj się do swojego konta w OLX.
# Krok 2. Wybierz edycję poprzez:
# stronę internetową OLX — kliknij Twoje konto → Aktywne → obok wybranego ogłoszenia wybierz przycisk Edytuj.
# aplikację mobilną OLX — kliknij Konto → Aktywne → obok wybranego ogłoszenia kliknij trzy kropki, a następnie wybierz Edytuj.
# Krok 3. Zmień w ogłoszeniu parametry, które Cię interesują.
# Krok 4. Kliknij przycisk Zmień ogłoszenie.
#
#
# 3
# Czy nowy System Ocen jest dostępny we wszystkich kategoriach?
# Oceny mogą wystawiać wyłącznie użytkownicy, którzy kupili przedmiot z Przesyłką OLX — i dopiero po jej otrzymaniu. Oznacza to, że oceny mogą być wystawiane wyłącznie po odebraniu przez Kupującego przedmiotu kupionego z Przesyłką OLX (kategorie, w których Przesyłka OLX jest dostępna). Gdy sprzedający otrzyma ocenę, jest ona wyświetlana na jego profilu i we wszystkich aktywnych ogłoszeniach (również tych, które nie mają włączonej Przesyłki OLX).
# Ogłoszenia w poniższych kategoriach nie będą wyświetlać oceny sprzedającego, ponieważ dotyczą usług lub przedmiotów, których nie można dostarczyć z Przesyłką OLX:
# Usługi
# Praca
# Nieruchomości
# Motoryzacja
# Wypożyczalnia
# Oznacza to, że:
# Jeśli sprzedający doda ogłoszenie w kategorii Usługi i ogłoszenie w kategorii Elektronika, jego ocena będzie wyświetlana tylko w ogłoszeniu w kategorii Elektronika.
# Jeżeli sprzedający dodał dwa ogłoszenia w kategorii Elektronika, ale tylko jedno z nich ma włączoną Przesyłkę OLX, jego ocena pojawi się w obu ogłoszeniach.
# System Ocen jest dostępny na stronie internetowej, stronie mobilnej i w wersji 4.95.1 (lub nowszej) aplikacji OLX na urządzenia z systemem iOS oraz w wersji 5.98.2 (lub nowszej) aplikacji OLX na urządzenia z systemem Android.
#
#
# 4
# Jak przedłużyć ogłoszenie?
# Każde ogłoszenie jest aktywne 30 dni od dnia publikacji. Po tym czasie wygaśnie i trafi do zakładki Zakończone. Jeśli chcesz aby Twoja oferta była nadal aktualna:
# użyj Przedłuż — ogłoszenie odnowi się na kolejne 30 dni (przycisk pojawi się na 3 dni przed wygaśnięciem ogłoszenia),
# włącz Autoprzedłużenie — ogłoszenie będzie odnawiać się automatycznie co 30 dni. Jeśli przekroczysz limit bezpłatnych ogłoszeń w danej kategorii / zmieni się prowizja za „Zapłać jeśli sprzedasz" / nie będziesz mieć ogłoszeń w ramach wykupionego pakiet, Twoje ogłoszenie trafi do zakładki Ogłoszenia / Nieopłacone. Możesz je stamtąd aktywować ponownie.
# Jeśli wygasło kilka ogłoszeń, zaznacz ich większą liczbę i za jednym kliknięciem aktywuj je ponownie — opcja będzie działać dla ogłoszeń, które mogą zostać opublikowane za darmo, w ramach limitu lub pakietu. Jeśli chcesz opublikować kilka płatnych ogłoszeń, każde z nich trzeba będzie aktywować pojedynczo.
# Aby przedłużyć ogłoszenie:
# Krok 1. Zaloguj się na swoje konto OLX.
# Krok 2. Przejdź do zakładki Ogłoszenia / Aktywne.
# Krok 3. Przy wybranym ogłoszeniu włącz Autoprzedłużenie lub kliknij przycisk Przedłuż.
#
#
#
#
#
# Pytanie: {'question': 'Jeśli komentarze tekstowe będą dostępne, czy mogę ich użyć do poprzednich ocen?', 'document': 'ea83195e'}
# Oczekiwany dokument: ['Czy mogę wystawić komentarz tekstowy w ocenie?']
# Oczekiwany dokument: ['W tej chwili nie. Funkcja ta jest planowana w przyszłej wersji nowego Systemu Ocen. Kiedy będzie gotowa, nie będziesz mógł/a z niej skorzystać do ocen wystawionych przed jej udostępnieniem (nie wstecznie).']
#
# Znalezione dokumenty:
# 0
# Co to jest „poprzednia ocena”?
# Jeśli widzisz „poprzednią ocenę” na profilu sprzedającego lub w ogłoszeniach (albo w zakładce Otrzymane oceny), oznacza to, że sprzedający (lub Ty) otrzymaliście oceny, gdy poprzedni system był dostępny.
# Do końca lipca 2024 roku nadal będzie można zobaczyć ocenę, jaką każdy sprzedający miał w poprzednim systemie. Pamiętaj, że ogólna ocena sprzedającego nie była po prostu średnią pojedynczych ocen. Poprzedni system zainspirowany był koncepcją NPS (ang. Net Promoter System), który opiera się na bilansie różnych rodzajów ocen użytkowników. Dlatego wyświetlana archiwalna ocena nie stanowi matematycznej średniej, stosowanej w innych, popularnych modelach systemu ocen. Poprzedni system działał w taki sposób, że wystawionym ocenom „źle”, „dobrze” i „rewelacyjnie” przypisywał określoną wagę (odpowiednio -2, +1 i +2). Następnie oceny te były przekształcane na ocenę jakościową w przedziale 0-10, wg. schematu: a) punkty 0 do 2,5 „nie polecam”, b) od 2,5 do 5 „nieźle”, c) od 5 do 7,5 „dobrze, d) od 7,5 do 10 „rewelacyjnie”.
# Aby dowiedzieć się więcej o poprzednich ocenach przeczytaj dodatkowe informacje o tym, jak działał poprzedni system.
#
#
# 1
# Co oznaczają tagi w systemie ocen?
# Tagi to wybrane aspekty zapewniające dodatkowe informacje do oceny w postaci gwiazdek. Będziesz mógł wybrać następujący tag:
# Nieobowiązkowy, jeśli przyznałeś sprzedającemu cztery lub pięć gwiazdek.
# Obowiązkowy, jeżeli przyznałeś sprzedającemu trzy gwiazdki lub mniej.
# Istnieją pozytywne i negatywne tagi. Negatywne tagi będą widoczne tylko wtedy, gdy przyznasz sprzedającemu 3 gwiazdki lub mniej. Pozytywne tagi będą widoczne tylko wtedy, gdy przyznasz sprzedającemu 4 lub 5 gwiazdek.
# Tagi te zostały wcześniej określone na podstawie badania przeprowadzonego wśród naszych użytkowników. Odzwierciedlają to, na co użytkownicy zwracają największą uwagę, gdy kogoś oceniają lub gdy ktoś ocenia ich. Obejmują one następujące tematy:
# Przedmiot (przedmiot zgodny z opisem, przedmiot niezgodny z opisem)
# Opakowanie (bezpieczne opakowanie, niedbałe opakowanie)
# Dostawa (szybko nadane, wolno nadane)
# Komunikacja (profesjonalna, nieprofesjonalna)
# Grzeczność (uprzejmy, nieuprzejmy)
# Cena (uczciwa cena, zawyżona)
# Tagi te mogą ulec zmianie — ale nawet jeśli tak się stanie, dodane wybrane przez Ciebie dotychczas tagi zawsze pozostaną takie same.
#
#
# 2
# Czy mogę wystawić ocenę, jeśli zamówienie zostało anulowane?
# Nie, jest to możliwe tylko w przypadku, gdy zamówienie zostało dostarczone. Oznacza to, że sprzedającego można ocenić tylko wtedy, gdy kupujący otrzyma przedmiot, który od niego kupił z Przesyłką OLX.
# Nie wystarczy, że przedmiot dotrze do punktu odbioru — kupujący musi go odebrać, zanim będzie mógł wystawić ocenę.
#
#
# 3
# Gdzie wyświetlane są oceny?
# Oceny są wyświetlane w trzech miejscach:
# W ogłoszeniach każdego sprzedającego – informacje te są widoczne dla wszystkich i obejmują:
# Łączną ocenę sprzedającego w skali od jeden do pięciu. Łączna ocena jest średnią arytmetyczną ocen indywidualnych.
# Liczbę otrzymanych ocen
# Na profilu sprzedającego – informacje te są widoczne dla wszystkich, obejmują one:
# Analizę ile razy przyznano każdą ocenę w postaci gwiazdek (np. pięć ocen 1- gwiazdkowych, piętnaście ocen 4-gwiazdkowych itp.);
# Jak często wybrano określony tag (np. 10 kupujących wybrało tag „Przedmiot zgodny z opisem”);
# Listę wszystkich ocen, które otrzymał sprzedający, uporządkowaną od najnowszych do najstarszych. Lista zawiera:
# Ocenę (liczbę gwiazdek).
# Nazwę ogłoszenia/przedmiotu związanego z oceną.
# Nazwę użytkownika na OLX.
# Datę przyznania oceny.
# Wszystkie tagi wybrane przez kupującego w celu uzasadnienia oceny.
# W zakładkach Otrzymane oceny i Wystawione oceny – informacje dostępne w tych zakładkach są prywatne dla każdego użytkownika.
#
#
# 4
# Podanie nieprawdziwych danych
# Użytkownik ma obowiązek w procesie Rejestracji oraz w toku korzystania z Serwisu podać dane prawdziwe, poprawne i aktualne i do których wykorzystywania jest uprawniony. Użytkownik zobowiązany jest do aktualizacji danych w razie ich zmiany. Grupa OLX ma prawo do blokady Konta w przypadku, gdy podane dane nie będą spełniały powyższych wymogów, zgodnie z procedurą określoną w punkcie 13 Regulaminu.
#
#
#
#
#
# Pytanie: {'question': 'Czy na OLX mogę sprzedawać przedmioty, które są przedmiotem sporu sądowego?', 'document': 'bf80eb5e'}
# Oczekiwany dokument: ['13.1 Użytkownik uprawniony jest do korzystania z Serwisu zgodnie z jego przeznaczeniem,']
# Oczekiwany dokument: ['w granicach prawa i dobrych obyczajów obowiązujących społeczeństwo informacyjne, z poszanowaniem praw i dóbr innych osób. W szczególności, Użytkownik zobowiązuje się do:\nniepodejmowania działań, które mogłyby zakłócić prawidłowe funkcjonowanie Serwisu, w tym do nieingerowania w zawartość Serwisu, Konta lub Kont innych Użytkowników, czy też w elementy informatyczne Serwisu;\nniepodejmowania działań bezprawnych, w tym przesyłania lub publikowania z wykorzystaniem funkcjonalności Serwisu treści naruszających przepisy prawa, dobra osobiste, treści zawierających lub rozpowszechniających pornografię dziecięcą lub treści terrorystycznych i naruszających cudze prawa własności intelektualnej, a także treści o charakterze dyskryminującym lub rasistowskim;\nnieprowadzenia z wykorzystaniem funkcjonalności Serwisu sprzedaży (lub niepodejmowania innych mających podobny skutek działań) Przedmiotów wymienionych Załączniku nr 5 “Przedmioty zakazane i dopuszczone warunkowo” lub prowadzenia ich sprzedaży bez spełnienia warunków wymaganych zgodnie z Załącznikiem nr 5, a także innych Przedmiotów, o ile obrót nimi jest wyłączony ze względu na obowiązujące przepisy prawa, a także Przedmiotów pochodzących z kradzieży lub co do których toczy się spór sądowy lub administracyjny albo też Przedmiotów objętych postępowaniem egzekucyjnym lub wchodzących w skład masy upadłościowej lub sanacyjnej;\nniewprowadzania osób korzystających z Serwisu oraz Grupy OLX w błąd, np. poprzez podawanie nieprawdziwych informacji dotyczących Przedmiotu albo zatajenie istotnych informacji;\npowstrzymywania się od działania w złej wierze, od nadużywania funkcjonalności Serwisu, korzystania z Serwisu niezgodnie z jego przeznaczeniem i wbrew Regulaminowi;\nniewprowadzanie w błąd Użytkowników co do stanu, cech i elementów Przedmiotu oraz innych warunków Transakcji - w tym okoliczności, o których mowa w pkt I.4 Załącznika nr 8 do Regulaminu.']
#
# Znalezione dokumenty:
# 0
# Jak założyć konto?
# Krok 1. Załóż konto na OLX poprzez:
# stronę internetową OLX — kliknij Twoje konto → Załóż konto lub kliknij tutaj.
# aplikację mobilną OLX — kliknij Konto → Zaloguj się → Załóż konto.
# Jeśli grafika jest nieczytelna, kliknij prawy przycisk myszy i wybierz „Otwórz grafikę w nowej karcie".
# Krok 2. Wpisz swój adres e-mail.
# Krok 3. Wpisz hasło, które ma minimum 8 znaków, w tym przynajmniej jedną dużą i małą literę, jedną cyfrę oraz znak specjalny.
# Krok 4. Kliknij Zarejestruj się.
# Krok 5. Przejdź do skrzynki mailowej i w wiadomości od OLX kliknij przycisk Aktywuj konto.
# Jeśli nie masz linku aktywacyjnego — napisz do nas.
# Na jednym koncie OLX nie można sprzedawać przedmiotów prywatnych i przedmiotów w ramach prowadzenia firmy. Do każdego typu sprzedaży (prywatnie, jako firma) wymagane jest oddzielne konto.
# Konto na OLX możesz założyć za pomocą konta na Facebooku. Wystarczy, że klikniesz tutaj. Następnie wybierz przycisk Kontynuuj z Facebook i postępuj zgodnie z wyświetlanymi wskazówkami. W ten sposób utworzymy konto w OLX na adresie e-mail powiązanym z Twoim kontem Facebook. Przed wyborem „Kontynuuj z Facebookiem" sprawdź, czy jesteś zalogowany/zalogowana na danym urządzeniu do konta Facebook.
#
#
# 1
# Jak mogę zobaczyć oceny, które wystawiłem?
# Wszystkie oceny, które wystawiasz jako kupujący, są widoczne w Twoje konto → Wystawione oceny. Są one uporządkowane od najnowszej do najstarszej. Klikając przycisk Pokaż obok każdej oceny zobaczysz:
# Nazwę użytkownika na OLX.
# Nazwę ogłoszenia/przedmiotu związanego z oceną.
# Datę zamówienia przedmiotu.
# Datę wystawienia oceny.
# Ocenę (liczbę gwiazdek).
# Wszystkie tagi wybrane przez Ciebie w celu uzasadnienia swojej oceny.
# Oceny mogą być usunięte w określonych przypadkach. Usunięcie oceny zostanie wyraźnie zaznaczone na liście wystawionych ocen wraz z powodem usunięcia (sprawdź dodatkowe informacje).
#
#
# 2
# Jak mogę zobaczyć oceny, które otrzymałem?
# Wszystkie oceny, które otrzymujesz jako sprzedający, są widoczne w Twoje konto → Otrzymane oceny i są uporządkowane od najnowszej do najstarszej. Zobaczysz:
# Ocenę (liczbę gwiazdek).
# Nazwę ogłoszenia/przedmiotu związanego z oceną wraz z identyfikatorem (ID).
# Nazwę użytkownika na OLX.
# Datę przyznania oceny.
# Wszystkie tagi wybrane przez kupującego w celu uzasadnienia oceny.
# Oceny można usunąć. Jeśli tak się stanie, zostanie to wyraźnie zaznaczone w na liście otrzymanych ocen wraz z powodem usunięcia (sprawdź dodatkowe informacje).
#
#
# 3
# Grupa OLX
# Grupa OLX sp. z o. o. z siedzibą w Poznaniu (ul. Królowej Jadwigi 43, 61-872, Poznań), wpisana do rejestru przedsiębiorców prowadzonego przez Sąd Rejonowy Poznań – Nowe Miasto i Wilda w Poznaniu, Wydział VIII Gospodarczy Krajowego Rejestru Sądowego pod numerem KRS: 0000568963, kapitał zakładowy 1 543 000,00 złotych, NIP: 7792433421. Kontakt z Grupą OLX jest możliwy pod adresem: pomoc@olx.pl lub za pomocą innych wskazanych w Serwisie kanałów komunikacji.
#
#
# 4
# Gdzie wyświetlane są oceny?
# Oceny są wyświetlane w trzech miejscach:
# W ogłoszeniach każdego sprzedającego – informacje te są widoczne dla wszystkich i obejmują:
# Łączną ocenę sprzedającego w skali od jeden do pięciu. Łączna ocena jest średnią arytmetyczną ocen indywidualnych.
# Liczbę otrzymanych ocen
# Na profilu sprzedającego – informacje te są widoczne dla wszystkich, obejmują one:
# Analizę ile razy przyznano każdą ocenę w postaci gwiazdek (np. pięć ocen 1- gwiazdkowych, piętnaście ocen 4-gwiazdkowych itp.);
# Jak często wybrano określony tag (np. 10 kupujących wybrało tag „Przedmiot zgodny z opisem”);
# Listę wszystkich ocen, które otrzymał sprzedający, uporządkowaną od najnowszych do najstarszych. Lista zawiera:
# Ocenę (liczbę gwiazdek).
# Nazwę ogłoszenia/przedmiotu związanego z oceną.
# Nazwę użytkownika na OLX.
# Datę przyznania oceny.
# Wszystkie tagi wybrane przez kupującego w celu uzasadnienia oceny.
# W zakładkach Otrzymane oceny i Wystawione oceny – informacje dostępne w tych zakładkach są prywatne dla każdego użytkownika.
#
#
#
#
#
# Pytanie: {'question': "Do kiedy będą widoczne 'poprzednie oceny' sprzedających na OLX?", 'document': '2f4756d7'}
# Oczekiwany dokument: ['Co to jest „poprzednia ocena”?']
# Oczekiwany dokument: ['Jeśli widzisz „poprzednią ocenę” na profilu sprzedającego lub w ogłoszeniach (albo w zakładce Otrzymane oceny), oznacza to, że sprzedający (lub Ty) otrzymaliście oceny, gdy poprzedni system był dostępny.\nDo końca lipca 2024 roku nadal będzie można zobaczyć ocenę, jaką każdy sprzedający miał w poprzednim systemie. Pamiętaj, że ogólna ocena sprzedającego nie była po prostu średnią pojedynczych ocen. Poprzedni system zainspirowany był koncepcją NPS (ang. Net Promoter System), który opiera się na bilansie różnych rodzajów ocen użytkowników. Dlatego wyświetlana archiwalna ocena nie stanowi matematycznej średniej, stosowanej w innych, popularnych modelach systemu ocen. Poprzedni system działał w taki sposób, że wystawionym ocenom „źle”, „dobrze” i „rewelacyjnie” przypisywał określoną wagę (odpowiednio -2, +1 i +2). Następnie oceny te były przekształcane na ocenę jakościową w przedziale 0-10, wg. schematu: a) punkty 0 do 2,5 „nie polecam”, b) od 2,5 do 5 „nieźle”, c) od 5 do 7,5 „dobrze, d) od 7,5 do 10 „rewelacyjnie”.\nAby dowiedzieć się więcej o poprzednich ocenach przeczytaj dodatkowe informacje o tym, jak działał poprzedni system.']
#
# Znalezione dokumenty:
# 0
# Gdzie wyświetlane są oceny?
# Oceny są wyświetlane w trzech miejscach:
# W ogłoszeniach każdego sprzedającego – informacje te są widoczne dla wszystkich i obejmują:
# Łączną ocenę sprzedającego w skali od jeden do pięciu. Łączna ocena jest średnią arytmetyczną ocen indywidualnych.
# Liczbę otrzymanych ocen
# Na profilu sprzedającego – informacje te są widoczne dla wszystkich, obejmują one:
# Analizę ile razy przyznano każdą ocenę w postaci gwiazdek (np. pięć ocen 1- gwiazdkowych, piętnaście ocen 4-gwiazdkowych itp.);
# Jak często wybrano określony tag (np. 10 kupujących wybrało tag „Przedmiot zgodny z opisem”);
# Listę wszystkich ocen, które otrzymał sprzedający, uporządkowaną od najnowszych do najstarszych. Lista zawiera:
# Ocenę (liczbę gwiazdek).
# Nazwę ogłoszenia/przedmiotu związanego z oceną.
# Nazwę użytkownika na OLX.
# Datę przyznania oceny.
# Wszystkie tagi wybrane przez kupującego w celu uzasadnienia oceny.
# W zakładkach Otrzymane oceny i Wystawione oceny – informacje dostępne w tych zakładkach są prywatne dla każdego użytkownika.
#
#
# 1
# Czy mogę odzyskać poprzednie oceny?
# Tak, możesz poprosić o listę wszystkich ocen, które otrzymałeś w przeszłości. Aby to zrobić, zaloguj się na swoje konto OLX za pomocą strony internetowej (na komputerze, nie na telefonie) i przejdź do Ustawienia → Zarządzanie kontem → Wyślij wniosek o dane. W ciągu 30 dni prześlemy plik ZIP na Twój adres e-mail. Plik będzie zawierał kilka plików CSV, w tym pliki ze wszystkimi ocenami otrzymanymi i wystawionymi w poprzednim Systemie Ocen.
#
#
# 2
# Słownik systemu ocen
# Ocena: Liczba wyrażona w postaci gwiazdek, używana przez kupujących do oceny zakupu u sprzedającego.
# Gwiazdki: Pozwalają ocenić zadowolenie kupującego z przebiegu transakcji z Przesyłką OLX z danym sprzedającym. Kupujący mogą oceniać sprzedających używając od jednej do pięciu gwiazdek.
# Tagi: Wybrane, określone wcześniej pozytywne i negatywne aspekty, które można wybrać, aby uzasadnić wystawioną oceną. Pod uwagę branych jest kilka czynników, takich jak opakowanie, szybkość dostawy i komunikacja.
# Łączna ocena sprzedającego: Łączna ocena sprzedającego to średnia wszystkich ocen (liczba gwiazdek) otrzymanych od kupujących. Jest wyrażana w postaci liczby od 1 do 5 i służy do oceny działań oraz wiarygodności sprzedającego na OLX. Jest to jeden z czynników, które pomagają potencjalnym nabywcom podejmować świadome decyzje związane z zakupami.
# Zweryfikowana ocena: Ocena dotycząca transakcji z Przesyłką OLX, wystawiona po odebraniu  przesyłki przez kupującego.
# Prośba o ocenę: Sposób, w jaki prosimy kupującego o wystawienie oceny za pośrednictwem wiadomości e-mail i (lub) powiadomienia push.
#
#
# 3
# Czy nowy System Ocen jest dostępny we wszystkich kategoriach?
# Oceny mogą wystawiać wyłącznie użytkownicy, którzy kupili przedmiot z Przesyłką OLX — i dopiero po jej otrzymaniu. Oznacza to, że oceny mogą być wystawiane wyłącznie po odebraniu przez Kupującego przedmiotu kupionego z Przesyłką OLX (kategorie, w których Przesyłka OLX jest dostępna). Gdy sprzedający otrzyma ocenę, jest ona wyświetlana na jego profilu i we wszystkich aktywnych ogłoszeniach (również tych, które nie mają włączonej Przesyłki OLX).
# Ogłoszenia w poniższych kategoriach nie będą wyświetlać oceny sprzedającego, ponieważ dotyczą usług lub przedmiotów, których nie można dostarczyć z Przesyłką OLX:
# Usługi
# Praca
# Nieruchomości
# Motoryzacja
# Wypożyczalnia
# Oznacza to, że:
# Jeśli sprzedający doda ogłoszenie w kategorii Usługi i ogłoszenie w kategorii Elektronika, jego ocena będzie wyświetlana tylko w ogłoszeniu w kategorii Elektronika.
# Jeżeli sprzedający dodał dwa ogłoszenia w kategorii Elektronika, ale tylko jedno z nich ma włączoną Przesyłkę OLX, jego ocena pojawi się w obu ogłoszeniach.
# System Ocen jest dostępny na stronie internetowej, stronie mobilnej i w wersji 4.95.1 (lub nowszej) aplikacji OLX na urządzenia z systemem iOS oraz w wersji 5.98.2 (lub nowszej) aplikacji OLX na urządzenia z systemem Android.
#
#
# 4
# Jak mogę zobaczyć oceny, które wystawiłem?
# Wszystkie oceny, które wystawiasz jako kupujący, są widoczne w Twoje konto → Wystawione oceny. Są one uporządkowane od najnowszej do najstarszej. Klikając przycisk Pokaż obok każdej oceny zobaczysz:
# Nazwę użytkownika na OLX.
# Nazwę ogłoszenia/przedmiotu związanego z oceną.
# Datę zamówienia przedmiotu.
# Datę wystawienia oceny.
# Ocenę (liczbę gwiazdek).
# Wszystkie tagi wybrane przez Ciebie w celu uzasadnienia swojej oceny.
# Oceny mogą być usunięte w określonych przypadkach. Usunięcie oceny zostanie wyraźnie zaznaczone na liście wystawionych ocen wraz z powodem usunięcia (sprawdź dodatkowe informacje).
#
#
#
#
#
# Pytanie: {'question': 'Jak mogę ustawić automatyczne przedłużanie ogłoszenia na OLX?', 'document': '790a7ddb'}
# Oczekiwany dokument: ['Jak przedłużyć ogłoszenie?']
# Oczekiwany dokument: ['Każde ogłoszenie jest aktywne 30 dni od dnia publikacji. Po tym czasie wygaśnie i trafi do zakładki Zakończone. Jeśli chcesz aby Twoja oferta była nadal aktualna:\nużyj Przedłuż — ogłoszenie odnowi się na kolejne 30 dni (przycisk pojawi się na 3 dni przed wygaśnięciem ogłoszenia),\nwłącz Autoprzedłużenie — ogłoszenie będzie odnawiać się automatycznie co 30 dni. Jeśli przekroczysz limit bezpłatnych ogłoszeń w danej kategorii / zmieni się prowizja za „Zapłać jeśli sprzedasz" / nie będziesz mieć ogłoszeń w ramach wykupionego pakiet, Twoje ogłoszenie trafi do zakładki Ogłoszenia / Nieopłacone. Możesz je stamtąd aktywować ponownie.\nJeśli wygasło kilka ogłoszeń, zaznacz ich większą liczbę i za jednym kliknięciem aktywuj je ponownie — opcja będzie działać dla ogłoszeń, które mogą zostać opublikowane za darmo, w ramach limitu lub pakietu. Jeśli chcesz opublikować kilka płatnych ogłoszeń, każde z nich trzeba będzie aktywować pojedynczo.\nAby przedłużyć ogłoszenie:\nKrok 1. Zaloguj się na swoje konto OLX.\nKrok 2. Przejdź do zakładki Ogłoszenia / Aktywne.\nKrok 3. Przy wybranym ogłoszeniu włącz Autoprzedłużenie lub kliknij przycisk Przedłuż.']
#
# Znalezione dokumenty:
# 0
# Jak zakończyć ogłoszenie?
# Aby zakończyć swoje ogłoszenie:
# Krok 1. Zaloguj się na swoje konto OLX.
# Krok 2. Jeśli korzystasz z:
# strony internetowej OLX — kliknij Twoje konto → Ogłoszenia / Aktywne → przy wybranym ogłoszeniu kliknij Zakończ.
# aplikacji mobilnej OLX — kliknij Konto → przy wybranym ogłoszeniu kliknij trzy kropki → wybierz przycisk Zakończ.
# Ogłoszenie możesz przywrócić w dowolnym momencie. Aby to zrobić, przejdź do zakładki Zakończone i przy danym ogłoszeniu kliknij Aktywuj. Jeżeli chcesz trwale usunąć ogłoszenie, kliknij Usuń z listy moich ogłoszeń. Po wybraniu tego przycisku, odzyskanie oferty nie będzie już możliwe.
#
#
# 1
# Jak dodać ogłoszenie?
# Aby dodać ogłoszenie:
# Krok 1. Zaloguj się do swojego konta w OLX.
# Krok 2. Jeśli korzystasz z:
# strony internetowej OLX — kliknij przycisk Dodaj ogłoszenie — znajdziesz go w prawym, górnym rogu.
# aplikacji mobilnej OLX — kliknij przycisk Dodaj — znajdziesz go na dole ekranu.
# Dodaj_ogłoszenie.png
# Jeśli grafika jest nieczytelna, kliknij prawy przycisk myszy i wybierz „Otwórz grafikę w nowej karcie".
# Krok 3. Uzupełnij szczegóły ogłoszenia.
# Tytuł
# Wpisz tytuł ogłoszenia. Po słowach z tytułu ogłoszenia Użytkownicy mogą wyszukać Twoją ofertę. Pamiętaj, aby nie pisać tylko wielkimi literami.
# Kategoria
# Wybierz kategorię sprzedawanego przedmiotu samodzielnie na podstawie naszych podpowiedzi lub skorzystaj z dostępnej listy. Jeżeli chcesz się upewnić, że wybierasz odpowiednią kategorię, zajrzyj tutaj.
# Cena
# Podaj cenę. Powinna ona odzwierciedlać wartość przedmiotu. Możesz również wybrać opcję Za darmo lub Zamienię. Pamiętaj, aby w ogłoszeniu wpisać rzeczywistą, oczekiwaną kwotę całkowitą brutto (w polskiej walucie).
# Opcje „Za darmo” oraz „Zamienię” nie są dostępne w kategorii Motoryzacja, w części podkategorii Nieruchomości oraz w kategorii Rolnictwo: Ciągniki, Maszyny rolnicze, Przyczepy, Części do maszyn rolniczych, Opony rolnicze.
# W niektórych kategoriach podanie ceny nie jest możliwe — na przykład w kategoriach usługowych. Możesz wtedy zamieścić cenę usługi w treści oferty.
# Typ ogłoszenia
# Typ ogłoszenia (osoba prywatna/firma) zostanie przypisany automatycznie po złożeniu deklaracji, w jaki sposób sprzedajesz na OLX. Pamiętaj, że deklaracja jest przypisana do wszystkich Twoich ogłoszeń i jej zmiana jest niemożliwa.
# Opis
# W tym miejscu podaj wszystkie szczegóły dotyczące przedmiotu/usługi. Zadbaj o szczegółowy i przejrzysty opis. W przypadku sprzedaży przedmiotu opisz stan, użyteczność, podaj parametry oraz ewentualne wady.
# Zdjęcia
# Kliknij Dodaj zdjęcie lub kliknij symbol aparatu, aby dodać zdjęcia, które najlepiej odzwierciedlą Twój przedmiot. Zadbaj o dobrą jakość zdjęć (maksymalna wielkość to 5 MB (format 4:3) lub 1500 x 1205 pikseli. Akceptowane formaty to: jpg, jpeg, png).
# Jeżeli chcesz się dowiedzieć, jak powinny wyglądać dobre zdjęcia, zapraszamy do naszego poradnika Jak zrobić atrakcyjne zdjęcia?
# Przypominamy także, że zgodnie z naszymi Zasadami, dodane zdjęcia:
# → nie mogą pochodzić z Internetu (łamią wtedy bowiem prawa autorskie),
# → powinny przedstawiać wyłącznie oferowany przedmiot,
# → nie powinny zawierać danych kontaktowych np. numeru telefonu.
# W kategorii Praca dodanie zdjęcia nie będzie możliwe.
# Dane kontaktowe i lokalizacja
# → Wybierz miejscowość i dzielnicę, w której można obejrzeć Twój przedmiot lub w której wykonujesz usługę. Użytkownicy nie będę widzieć Twojego dokładnego adresu.
# → Wpisz osobę kontaktową — będzie ona pojawiać się w każdym ogłoszeniu, które dodasz.
# → Wskazany adres e-mail jest powiązany z kontem.
# → Numer telefonu — Użytkownicy będą kontaktować się z Tobą poprzez wiadomości OLX. Jeżeli chcesz, aby kontaktowali się z Tobą również telefonicznie — podaj swój numer telefonu. Aby podać więcej niż jeden numer telefonu — rozdziel je przecinkiem i spacją, np. „601234XXX, 601234YYY".
# Dane takie jak: adres e-mail, miejscowość, numer telefonu oraz imię osoby kontaktowej możesz uzupełnić / zmienić w zakładce Ustawienia / Dane kontaktowe. Będą one widoczne podczas dodawania kolejnych ogłoszeń.
# Dodatkowe parametry
# W części kategorii konieczne będzie dodanie dodatkowych parametrów. W kategorii Moda — rozmiar ubrania, w kategorii Praca — rodzaj umowy, a w kategorii Motoryzacja/Części samochodowe — parametry oferowanej części. Wypełnij pola oznaczone gwiazdką.
# Krok 4. Jeżeli Twój przedmiot jest w kategorii, w której dostępne są Przesyłki OLX, dodaj tę opcję do swojego ogłoszenia. Sprawdź, jak to zrobić, klikając tutaj.
# Krok 5. Kliknij przycisk Dodaj ogłoszenie lub Zobacz przed dodaniem.
# Krok 6. Jeżeli:
# Twoje ogłoszenie należy do płatnych kategorii — opłać zamówienie.
# chcesz, aby Twoje ogłoszenie było lepiej widoczne, wybierz jeden z dostępnych pakietów promowań. Więcej o pakietach znajdziesz tutaj.
# Twoje ogłoszenie nie należy do płatnych kategorii i nie chcesz skorzystać z pakietu promowania, kliknij przycisk Nie promuj. Jeśli przycisk nie jest widoczny — odznacz wybrane promowanie.
# Wszystkie zasady zamieszczania ogłoszeń znajdziesz tutaj.
#
#
# 2
# Grupa OLX uprawniona jest do usunięcia Ogłoszenia lub zablokowania Konta jeśli zaistniało podejrzenie, że za pośrednictwem Ogłoszenia lub Konta mogło lub może dojść do działań zagrażających bezpieczeństwu innych Użytkowników w ramach Serwisu,
# jak również w przypadku, w którym Ogłoszenie negatywnie wpływa na dobre imię Grupy OLX lub w inny sposób szkodzi Grupie OLX.
#
#
# 3
# Czy oceny można usunąć? Kiedy i w jaki sposób?
# Tak, oceny mogą zostać usunięte, ale wyłącznie przez OLX i tylko wtedy, gdy nie są zgodne z naszym Regulaminem lub z przepisami prawa. Sprzedający ani kupujący nie mogą samodzielnie usuwać ocen.  Aby ocena została usunięta konieczne jest wskazanie powodu usunięcia, a także uzasadnienia, które to potwierdzi.
# Powód usunięcia
# Wyjaśnienie
# Nieprawdziwa ocena
# Ocena nie odzwierciedla rzeczywistego przebiegu Transakcji lub zawiera fałszywe lub nieuczciwe oskarżenie wobec sprzedającego (pkt 14a.11.a Regulaminu OLX).
# Ocena nie dotyczy transakcji
# Ocena nie dotyczy przebiegu transakcji z Przesyłką OLX z danym sprzedającym. Ocena mogła odnosić się do innej transakcji, stanowić recenzję nabytego towaru albo odnosić się do OLX (pkt 14a.11.b Regulaminu OLX).
# Samoocena
# Jedno lub kilka kont zostało utworzonych w celu sztucznego podwyższenia oceny sprzedającego (pkt 14a.11.c Regulaminu OLX).
# Błąd kupującego
# Ocena usunięta z powodu pomyłki lub przypadkowego wystawienia oceny niewłaściwemu sprzedającemu za zgodą kupującego (pkt 14a.11.d Regulaminu OLX).
# Sztuczna ocena
# Ocena wystawiona w celu sztucznego zawyżenia lub zaniżenia ogólnej oceny sprzedającego (pkt 14a.11.e Regulaminu OLX).
# Ocena z niewiarygodnego konta
# Ocena wystawiona została z konta utworzonego na podstawie tymczasowego adresu e-mail
# (pkt 14a.11.f Regulaminu OLX).
# Ocena wystawiona automatycznie
# Ocena została wystawiona w sposób wskazujący na zautomatyzowanie wystawienia (pkt 14a.11.g Regulaminu OLX).
# Ocena wystawiona za korzyść
# Ocena została wystawiona w zamian za korzyść, np. rabat albo gratis, (pkt 14a.11.h Regulaminu OLX).
# Ocena naruszająca prawo lub regulamin OLX
# Ocena wystawiona z naruszeniem innych postanowień regulaminu OLX lub przepisów prawa (pkt 14a.11.i Regulaminu OLX).
# Jako sprzedający możesz w dowolnym momencie poprosić nas o usunięcie oceny. Oto, jak to zrobisz:
# Skontaktuj się z nami za pomocą Centrum Pomocy;
# Wskaż ocenę, którą chcesz, abyśmy usunęli (identyfikator (ID) ogłoszenia, tytuł ogłoszenia, data wystawienia oceny, nazwę użytkownika);
# Wyjaśnij, dlaczego chcesz, abyśmy usunęli ocenę i wskaż stosowne dowody na uzasadnienie usunięcia oceny.
# Rozpatrzymy dokładnie Twoją sprawę i poinformujemy Cię o naszej decyzji w ciągu 14 dni. Jeżeli potwierdzimy, że istnieje ważny, wskazany w Regulaminie powód, aby usunąć ocenę:
# Zarówno Ty, jak i kupujący zostaniecie o tym powiadomieni poprzez wiadomość e-mail. Powód usunięcia oceny jest zawsze udostępniany kupującemu i sprzedającemu.
# Ocena zostanie usunięta z profilu sprzedającego.
# Ocena nie będzie zaliczana do obliczenia oceny sprzedającego.
# Ocena sprzedającego zostanie obliczona ponownie.
# Zarówno Ty, jak i kupujący będziecie mogli nadal zobaczyć ocenę w zakładce Otrzymane oceny i Wystawione oceny – ocena będzie mieć oznaczenie „Usunięto” i będzie widoczna tylko dla Ciebie i
# kupującego wraz z powodem usunięcia.
# Należy pamiętać: Jeśli otrzymana ocena zostanie usunięta, kupujący nie będzie mógł ponownie wystawić Ci oceny dotyczącej tej konkretnej sprzedaży.
# Jako kupujący możesz także poprosić nas o usunięcie oceny, którą wystawiłeś w przeszłości. Oto, jak to zrobisz:
# Skontaktuj się z nami za pomocą Centrum Pomocy;
# Wskaż ocenę, którą chcesz, abyśmy usunęli (tytuł ogłoszenia, data wystawienia oceny, nazwę użytkownika);
# Wyjaśnij, dlaczego chcesz, abyśmy usunęli ocenę.
# Rozpatrzymy dokładnie Twoją sprawę i poinformujemy Cię o naszej decyzji w ciągu 14 dni. Jeżeli potwierdzimy, że istnieje ważny i wskazany w Regulaminie powód, aby usunąć ocenę:
# Zarówno Ty, jak i sprzedający zostaniecie o tym powiadomieni poprzez wiadomość e-mail. Powód usunięcia oceny jest zawsze udostępniany sprzedającemu.
# Ocena zostanie usunięta z profilu sprzedającego.
# Ocena nie będzie zaliczana do obliczenia oceny sprzedającego.
# Ocena sprzedającego zostanie obliczona ponownie.
# Zarówno Ty, jak i sprzedający będziecie mogli nadal zobaczyć ocenę w zakładce Otrzymane oceny i Wystawione oceny – ocena będzie mieć oznaczenie „Usunięto” i będzie widoczna tylko dla Ciebie i sprzedającego wraz z powodem usunięcia.
# Należy pamiętać: Jeśli wystawiona ocena zostanie usunięta, nie będziesz mógł ponownie ocenić sprzedającego w związku z tą konkretną sprzedażą.
#
#
# 4
# Jak mogę zobaczyć oceny, które wystawiłem?
# Wszystkie oceny, które wystawiasz jako kupujący, są widoczne w Twoje konto → Wystawione oceny. Są one uporządkowane od najnowszej do najstarszej. Klikając przycisk Pokaż obok każdej oceny zobaczysz:
# Nazwę użytkownika na OLX.
# Nazwę ogłoszenia/przedmiotu związanego z oceną.
# Datę zamówienia przedmiotu.
# Datę wystawienia oceny.
# Ocenę (liczbę gwiazdek).
# Wszystkie tagi wybrane przez Ciebie w celu uzasadnienia swojej oceny.
# Oceny mogą być usunięte w określonych przypadkach. Usunięcie oceny zostanie wyraźnie zaznaczone na liście wystawionych ocen wraz z powodem usunięcia (sprawdź dodatkowe informacje).

# %% [markdown]
# ## Increasing number of documents retrieved to 15
#
# Seems like we don't have a good candidate. Let's check if we can make it work better if LLM has more documents to choose from.

# %%
import re 

def search_reranked_retrieval(q, k=15, max_doc_candidate_length=200):
    
    doc_id = q['document']
    doc = [doc for doc in documents if doc['id'] == doc_id][0]
    found_docs = question_hybrid(q, k=k)
    found_docs_questions = ['id: ' + doc['id'] + ". " + doc['question'] + " " + doc['text'] for doc in found_docs]

    prompt = prompt_template.format(
        k=5,
        section=doc['section'],
        question=doc['question'],
        text=doc['text'],
        doc1_question=found_docs_questions[0][:max_doc_candidate_length],
        doc2_question=found_docs_questions[1][:max_doc_candidate_length],
        doc3_question=found_docs_questions[2][:max_doc_candidate_length],
        doc4_question=found_docs_questions[3][:max_doc_candidate_length],
        doc5_question=found_docs_questions[4][:max_doc_candidate_length],
        doc6_question=found_docs_questions[5][:max_doc_candidate_length],
        doc7_question=found_docs_questions[6][:max_doc_candidate_length],
        doc8_question=found_docs_questions[7][:max_doc_candidate_length],
        doc9_question=found_docs_questions[8][:max_doc_candidate_length],
        doc10_question=found_docs_questions[9][:max_doc_candidate_length],
        doc11_question=found_docs_questions[10][:max_doc_candidate_length],
        doc12_question=found_docs_questions[11][:max_doc_candidate_length],
        doc13_question=found_docs_questions[12][:max_doc_candidate_length],
        doc14_question=found_docs_questions[13][:max_doc_candidate_length],
        doc15_question=found_docs_questions[14][:max_doc_candidate_length],
    )

    response = client.chat.completions.create(
        model='gpt-4o',
        messages=[{"role": "user", "content": prompt}]
    )

    json_response = response.choices[0].message.content
    
    if len(json_response) == 0:
        logger.info("Empty response from GPT-4o")
        return [doc['id'] for doc in found_docs[:5]]
    
    # quick preprocessing
    json_response_preprocessed = re.sub(r'```json', '', json_response)
    json_json_response_preprocessedresponse = re.sub(r'```', '', json_response_preprocessed)
    ids = json.loads(json_response)
    ids = [re.sub("id_", "", str(id)) for id in ids]
    ids = [re.sub("id:", "", str(id)) for id in ids]
    ids = [id.strip() for id in ids]
    ids = [id for id in ids if len(id) > 2]
    
    if len(ids) > 5:
        logger.warning("More than 5 ids returned from GPT-4o")
        return ids[:5]
    elif len(ids) < 5:
        logger.warning("Less than 5 ids returned from GPT-4o after preprocessing")
        logger.warning(json_response)
        tmp_ids = ids + [doc['id'] for doc in found_docs if doc['id'] not in ids]
        logger.info(f"Returning {tmp_ids[:5]}")
        return tmp_ids[:5]
    else:
        return ids

# %%
def evaluate_reranking_more_options(ground_truth, search_function):
    relevance_total = []
    result_total = []

    for q in tqdm(ground_truth):
        time.sleep(0.25)
        doc_id = q['document']
        try:
            results = search_function(q, k=15)
        except Exception as e:
            logging.error(e)
            # empty list of results of length 10
            results = ['' for _ in range(15)]
        relevance = [d == doc_id for d in results]
        relevance_total.append(relevance)
        result_total.append(results)

    return {
        'results_total': result_total,
        'relevance_total': relevance_total,
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total),
    }

# %%
res_reranking_more_options = evaluate_reranking_more_options(ground_truth_updated, search_reranked_retrieval)

# %%
res_reranking_more_options
# Out:
# {'results_total': [['2ddb5f16',
#    'aa9e24ac',
#    'ff50559b',
#    'd30e6624',
#    'e8caa77b'],
#   ['e8caa77b', '6c146627', '4dcf8b35', '1106b1dc', 'aa9e24ac'],
#   ['33813c2c', '342037c3', '1106b1dc', '469cc1f8', 'b61f3a70'],
#   ['2ddb5f16', '6c146627', 'e8caa77b', 'bde8bc7c', 'd4e7a30b'],
#   ['2ddb5f16', '33813c2c', '943a92e0', '1106b1dc', '469cc1f8'],
#   ['2ddb5f16', '9e41cc6b', 'e8caa77b', '6c146627', '38edb241'],
#   ['943a92e0', '7e9de748', 'ce9623ca', 'd132587e', 'c4479dd3'],
#   ['943a92e0', 'd132587e', '78b8c86d', '2e80fa3d', '15542325'],
#   ['943a92e0', '9e41cc6b', '1106b1dc', 'c95af011', '469cc1f8'],
#   ['943a92e0', '2ddb5f16', '7e9de748', 'fbdcafed', '59d738e5'],
#   ['9e41cc6b', '943a92e0', '342037c3', '33813c2c', 'ce9623ca'],
#   ['9e41cc6b', 'd30e6624', '469cc1f8', '943a92e0', 'd132587e'],
#   ['9e41cc6b', '4dcf8b35', '943a92e0', '2ddb5f16', 'e8caa77b'],
#   ['9e41cc6b', '4dcf8b35', '943a92e0', '2ddb5f16', '7a78f438'],
#   ['9e41cc6b', '943a92e0', '0f5525bd', '342037c3', '33813c2c'],
#   ['7e9de748', '469cc1f8', '4dcf8b35', 'ec79b98a', '9e41cc6b'],
#   ['469cc1f8', '7e9de748', '0b78fb57', '9e41cc6b', '2ddb5f16'],
#   ['7e9de748', '469cc1f8', '943a92e0', '9e41cc6b', '2ddb5f16'],
#   ['7e9de748', '2ddb5f16', '9e41cc6b', '4dcf8b35', '943a92e0'],
#   ['9e41cc6b', 'ce9623ca', 'd30e6624', '2ddb5f16', '01f95cb6'],
#   ['469cc1f8', '0b78fb57', '9e41cc6b', '368caa05', 'b61f3a70'],
#   ['6.  0b78fb57',
#    '4.  9e41cc6b',
#    '1.  943a92e0',
#    '8.  ce9623ca',
#    '7.  342037c3'],
#   ['469cc1f8', '7e9de748', '943a92e0', '2ddb5f16', '9e41cc6b'],
#   ['469cc1f8', 'a74246e6', '6c146627', 'aa9e24ac', '01f95cb6'],
#   ['469cc1f8', 'f018251f', 'd30e6624', '9e41cc6b', '943a92e0'],
#   ['0b78fb57', '1106b1dc', 'e8caa77b', '01f95cb6', '38edb241'],
#   ['469cc1f8', '38edb241', '4dcf8b35', '9e41cc6b', '342037c3'],
#   ['38edb241', '342037c3', '4dcf8b35', '9a61f3a70', '1106b1dc'],
#   ['0b78fb57', '469cc1f8', 'aa9e24ac', '01f95cb6', '2ddb5f16'],
#   ['ce9623ca', '2ddb5f16', '4dcf8b35', '5a23b03', '943a92e0'],
#   ['4dcf8b35', '1106b1dc', '2ddb5f16', '7e9de748', '6a293a6d'],
#   ['4dcf8b35', '2ddb5f16', 'e8caa77b', '368caa05', '1106b1dc'],
#   ['4dcf8b35', '1106b1dc', '7c7a4947', 'c4479dd3', '0b78fb57'],
#   ['4dcf8b35', '1106b1dc', '2ddb5f16', 'e8caa77b', '6c146627'],
#   ['ec79b98a', '9e41cc6b', '7293f181', '7e9de748', '0f5525bd'],
#   ['e8caa77b', '342037c3', '4dcf8b35', '7e9de748', 'b61f3a70'],
#   ['e8caa77b', 'ad5b87dc', '4dcf8b35', '38edb241', 'ec79b98a'],
#   ['e8caa77b', '4dcf8b35', '342037c3', '2ddb5f16', '469cc1f8'],
#   ['e8caa77b', '7e9de748', '4dcf8b35', '469cc1f8', 'ad5b87dc'],
#   ['e8caa77b', '2ddb5f16', 'bdf287a5', '4dcf8b35', 'eefc3ee3'],
#   ['6c146627', '342037c3', '7c7a4947', '5c920aad', '2ddb5f16'],
#   ['6c146627', '7c7a4947', '342037c3', '1106b1dc', '469cc1f8'],
#   ['6c146627', 'b8121ab6', 'e3610c01', '2e80fa3d', '2f4756d7'],
#   ['6c146627', '4dcf8b35', '342037c3', '9e41cc6b', 'bdf287a5'],
#   ['6c146627', '7c7a4947', '342037c3', '9b920aad', '4dcf8b35'],
#   ['342037c3', '943a92e0', '38edb241', '7c7a4947', '790a7ddb'],
#   ['342037c3', '38edb241', '1106b1dc', '6c146627', '314ee8cf'],
#   ['342037c3', '7c7a4947', '6a293a6d', '5c920aad', '1106b1dc'],
#   ['342037c3', '790a7ddb', '943a92e0', 'd728141a', 'a4863842'],
#   ['342037c3', '7c7a4947', 'be4ae5c8', '790a7ddb', 'f151c2bb'],
#   ['be4ae5c8', 'd728141a', '342037c3', '314ee8cf', 'bdf287a5'],
#   ['342037c3', 'bdf287a5', '7c7a4947', 'd728141a', 'be4ae5c8'],
#   ['be4ae5c8', 'bdf287a5', '342037c3', '0f5525bd', '2f4756d7'],
#   ['be4ae5c8', 'bdf287a5', '7c7a4947', '342037c3', '6c146627'],
#   ['bdf287a5', '7c7a4947', '342037c3', '790a7ddb', '314ee8cf'],
#   ['7c7a4947', '7293f181', '01f95cb6', '342037c3', 'bdf287a5'],
#   ['7c7a4947', 'bdf287a5', '6c146627', '7293f181', '342037c3'],
#   ['7c7a4947', 'bdf287a5', '1106b1dc', '9c146627', 'ec79b98a'],
#   ['7c7a4947', '342037c3', '1106b1dc', '314ee8cf', '790a7ddb'],
#   ['7c7a4947', '342037c3', '790a7ddb', '2ddb5f16', '38edb241'],
#   ['790a7ddb', 'bdf287a5', '342037c3', '7c7a4947', 'eefc3ee3'],
#   ['342037c3', '1106b1dc', 'bdf287a5', '6a293a6d', 'ea07084a'],
#   ['790a7ddb', '8e41cc6b', 'fc91e6ff', '339ea69d', '879acb3b'],
#   ['790a7ddb', '1106b1dc', '33813c2c', '0f5525bd', '469cc1f8'],
#   ['790a7ddb', '7c7a4947', '51a23b03', '342037c3', '6a293a6d'],
#   ['1106b1dc', '790a7ddb', '342037c3', '7c7a4947', 'bdf287a5'],
#   ['1106b1dc', '342037c3', '790a7ddb', '4dcf8b35', '943a92e0'],
#   ['1106b1dc', '342037c3', '4dcf8b35', 'e8caa77b', '6c146627'],
#   ['1106b1dc', '790a7ddb', 'bde8bc7c', '9e41cc6b', 'd728141a'],
#   ['1106b1dc', '368caa05', 'eefc3ee3', '469cc1f8', 'c95af011'],
#   ['bdf287a5', '342037c3', '1106b1dc', '790a7ddb', '7293f181'],
#   ['bdf287a5', 'be4ae5c8', '342037c3', '01f95cb6', 'c95af011'],
#   ['bdf287a5', '7c7a4947', '6c146627', '342037c3', '059738e5'],
#   ['bdf287a5', '7c7a4947', 'be4ae5c8', '6c146627', '342037c3'],
#   ['bdf287a5', 'be4ae5c8', '790a7ddb', '469cc1f8', '342037c3'],
#   ['2e80fa3d', 'd132587e', '78b8c86d', 'bde8bc7c', 'd4e7a30b'],
#   ['2e80fa3d', 'eefc3ee3', '342037c3', 'bde8bc7c', 'd4e7a30b'],
#   ['2e80fa3d', 'eefc3ee3', '314ee8cf', '78b8c86d', '0eb46939'],
#   ['2e80fa3d', '1106b1dc', '342037c3', 'ce9623ca', '059738e5'],
#   ['2e80fa3d', '1106b1dc', '368caa05', '314ee8cf', '78b8c86d'],
#   ['d132587e', '2e80fa3d', '943a92e0', '78b8c86d', '60a68db3'],
#   ['d132587e', '469cc1f8', 'eefc3ee3', 'd4e7a30b', 'bde8bc7c'],
#   ['d132587e', '943a92e0', 'e8caa77b', '0b78fb57', '953c5400'],
#   ['d132587e', '943a92e0', 'bde8bc7c', 'd4e7a30b', '953c5400'],
#   ['d132587e', '943a92e0', '15542325', 'd4e7a30b', 'bde8bc7c'],
#   ['c95af011', '342037c3', 'ce9623ca', '1106b1dc', 'ad5b87dc'],
#   ['c95af011', '01f95cb6', '342037c3', '2ddb5f16', '1f9773b9'],
#   ['c95af011', 'b61f3a70', '342037c3', 'ce9623ca', '314ee8cf'],
#   ['c95af011', '342037c3', '38edb241', 'ec79b98a', 'eefc3ee3'],
#   ['c95af011', '342037c3', 'e3610c01', '37570bca', '790a7ddb'],
#   ['38edb241', '01f95cb6', '2e80fa3d', 'ce9623ca', '2ddb5f16'],
#   ['38edb241', '314ee8cf', 'bde8bc7c', '78b8c86d', 'd4e7a30b'],
#   ['38edb241', '6c146627', '314ee8cf', 'd132587e', '7c7a4947'],
#   ['38edb241', '469cc1f8', '7c7a4947', 'd30e6624', 'ce9623ca'],
#   ['38edb241', '1106b1dc', '943a92e0', '7c7a4947', '6c146627'],
#   ['e55a6ace', '469cc1f8', '4dcf8b35', 'e8caa77b', '7e9de748'],
#   ['e55a6ace', '943a92e0', 'ad5b87dc', '790a7ddb', '9e41cc6b'],
#   ['e55a6ace', 'ad5b87dc', '60a68db3', 'b6427a45', 'd132587e'],
#   ['e55a6ace', '953c5400', 'b7c49ccc', '60a68db3', 'b6427a45'],
#   ['e55a6ace', '469cc1f8', 'eefc3ee3', 'd132587e', '1106b1dc'],
#   ['953c5400', 'ad5b87dc', 'e55a6ace', 'b7c49ccc', '60a68db3'],
#   ['953c5400', 'b7c49ccc', 'e55a6ace', 'ad5b87dc', '60a68db3'],
#   ['953c5400', 'b7c49ccc', 'b6427a45', '60a68db3', 'e8caa77b'],
#   ['953c5400', '2ddb5f16', '8caa77b', '4dcf8b35', 'ad5b87dc'],
#   ['953c5400', 'b7c49ccc', 'e55a6ace', '60a68db3', 'b6427a45'],
#   ['b7c49ccc', 'e55a6ace', '469cc1f8', '60a68db3', '953c5400'],
#   ['b7c49ccc', '953c5400', '60a68db3', 'b6427a45', 'e55a6ace'],
#   ['37570bca', '342037c3', '01f95cb6', 'ec79b98a', '2ddb5f16'],
#   ['b7c49ccc', '60a68db3', 'e55a6ace', 'e8caa77b', '2ddb5f16'],
#   ['b7c49ccc', '953c5400', 'e55a6ace', '60a68db3', 'b6427a45'],
#   ['b6427a45', 'ad5b87dc', '953c5400', 'b7c49ccc', '60a68db3'],
#   ['e55a6ace', '953c5400', 'b7c49ccc', 'ad5b87dc', '469cc1f8'],
#   ['b6427a45', 'e55a6ace', 'ce9623ca', '51a23b03', 'e8caa77b'],
#   ['b6427a45', 'b7c49ccc', '60a68db3', 'e55a6ace', '01f95cb6'],
#   ['1106b1dc', '342037c3', '469cc1f8', '38edb241', '790a7ddb'],
#   ['60a68db3', 'b6427a45', '953c5400', 'b7c49ccc', 'e55a6ace'],
#   ['60a68db3', 'b6427a45', '342037c3', 'e3610c01', 'd132587e'],
#   ['60a68db3', 'b7c49ccc', '953c5400', 'b6427a45', 'e55a6ace'],
#   ['60a68db3', 'e55a6ace', 'b6427a45', 'd132587e', 'fbdcafed'],
#   ['60a68db3', 'b6427a45', 'e55a6ace', 'eefc3ee3', 'd132587e'],
#   ['ad5b87dc', 'e55a6ace', '953c5400', 'b7c49ccc', '60a68db3'],
#   ['ad5b87dc', 'fbdcafed', 'e55a6ace', '2ddb5f16', '342037c3'],
#   ['ad5b87dc', '342037c3', 'd132587e', '953c5400', 'b7c49ccc'],
#   ['ad5b87dc', 'e55a6ace', 'b7c49ccc', '953c5400', '60a68db3'],
#   ['ad5b87dc', 'e55a6ace', 'eefc3ee3', '37570bca', 'fbdcafed'],
#   ['7acd2acc', '896d0dae', '51a23b03', '342037c3', '1106b1dc'],
#   ['7acd2acc', '1106b1dc', '342037c3', '7293f181', '896d0dae'],
#   ['7acd2acc', 'be4ae5c8', 'd728141a', '2f4756d7', '8c54d3a1'],
#   ['314ee8cf', '78b8c86d', 'e3610c01', 'b8121ab6', '0d5c9008'],
#   ['314ee8cf', 'eefc3ee3', '78b8c86d', 'bdf287a5', '7c7a4947'],
#   ['314ee8cf', 'e3610c01', '01f95cb6', 'be4ae5c8', '342037c3'],
#   ['e3610c01', '1106b1dc', '0d5c9008', 'c4479dd3', '2f4756d7'],
#   ['314ee8cf', '78b8c86d', '0eb46939', 'eefc3ee3', 'bde8bc7c'],
#   ['eefc3ee3', 'f7c6bf38', 'bde8bc7c', 'd4e7a30b', '78b8c86d'],
#   ['314ee8cf', 'eefc3ee3', 'bde8bc7c', 'd4e7a30b', '37570bca'],
#   ['eefc3ee3', 'bde8bc7c', 'd4e7a30b', '78b8c86d', '314ee8cf'],
#   ['eefc3ee3', '314ee8cf', 'bde8bc7c', 'd4e7a30b', '37570bca'],
#   ['eefc3ee3', 'd4e7a30b', '314ee8cf', 'bde8bc7c', '01f95cb6'],
#   ['f7c6bf38', '6c146627', 'd4e7a30b', 'bdf287a5', 'ea83195e'],
#   ['78b8c86d', '01f95cb6', 'bdf287a5', 'ec79b98a', '0d5c9008'],
#   ['f7c6bf38', '01f95cb6', 'eefc3ee3', '0eb46939', '2f4756d7'],
#   ['f7c6bf38', '01f95cb6', 'd4e7a30b', 'eefc3ee3', 'bde8bc7c'],
#   ['f7c6bf38', '01f95cb6', 'bdf287a5', 'b8121ab6', '2f4756d7'],
#   ['0eb46939', '5e043cfd', '314ee8cf', '37570bca', '01f95cb6'],
#   ['0eb46939', '2f4756d7', '37570bca', '7e043cfd', '314ee8cf'],
#   ['78b8c86d', 'd4e7a30b', 'bde8bc7c', '314ee8cf', '2f4756d7'],
#   ['78b8c86d', '314ee8cf', '0eb46939', 'e3610c01', 'c4479dd3'],
#   ['78b8c86d', '314ee8cf', '0eb46939', 'bde8bc7c', 'd4e7a30b'],
#   ['5e043cfd', '37570bca', 'f151c2bb', 'e3610c01', '2f4756d7'],
#   ['5e043cfd', 'f151c2bb', '7c95af011', 'b1f31cc0', '3ec8bd3d'],
#   ['5e043cfd', '37570bca', 'b1f31cc0', '2f4756d7', 'e3610c01'],
#   ['5e043cfd', '37570bca', 'b1f31cc0', '01f95cb6', '0eb46939'],
#   ['5e043cfd', '37570bca', 'f151c2bb', 'b1f31cc0', 'eefc3ee3'],
#   ['b1f31cc0', '0d5c9008', '37570bca', '5e043cfd', 'e3610c01'],
#   ['b1f31cc0', 'e3610c01', '6f1a2ca7', '0d5c9008', '5f2b8d35'],
#   ['b1f31cc0', '37570bca', '5e043cfd', '0d5c9008', '2f4756d7'],
#   ['b1f31cc0', 'eefc3ee3', '0d5c9008', 'c4479dd3', 'e3610c01'],
#   ['b1f31cc0', '37570bca', '0d5c9008', 'c4479dd3', 'e3610c01'],
#   ['ea83195e', '1f9773b9', 'ec79b98a', 'b8121ab6', '78b8c86d'],
#   ['ea83195e', '2f4756d7', '314ee8cf', 'f7c6bf38', '01f95cb6'],
#   ['ea83195e', '6c146627', '78b8c86d', '469cc1f8', 'ec79b98a'],
#   ['9ea83195e', '5e043cfd', 'b1f31cc0', 'b8121ab6', 'ec79b98a'],
#   ['2f4756d7', 'b1f31cc0', 'bde8bc7c', 'b8121ab6', '78b8c86d'],
#   ['c4479dd3', '0d5c9008', 'eefc3ee3', 'b8121ab6', '01f95cb6'],
#   ['e3610c01', '0d5c9008', 'c4479dd3', 'eefc3ee3', '01f95cb6'],
#   ['e3610c01', 'b8121ab6', '2f4756d7', 'c4479dd3', '6c26f482'],
#   ['e3610c01', 'c4479dd3', '0d5c9008', '2f4756d7', 'b8121ab6'],
#   ['e3610c01', 'c4479dd3', '0d5c9008', '2f4756d7', '01f95cb6'],
#   ['b8121ab6', 'f151c2bb', 'e3610c01', '314ee8cf', 'd30e6624'],
#   ['b8121ab6', '2f4756d7', '314ee8cf', 'eefc3ee3', '37570bca'],
#   ['b8121ab6', '2f4756d7', 'e3610c01', 'b1f31cc0', '5e043cfd'],
#   ['b8121ab6', '2f4756d7', '01f95cb6', 'c4479dd3', 'f151c2bb'],
#   ['b8121ab6', '4dd5d899', '2f4756d7', 'e3610c01', 'c4479dd3'],
#   ['2f4756d7', 'b8121ab6', '01f95cb6', 'f151c2bb', 'e3610c01'],
#   ['2f4756d7', 'b8121ab6', '0d5c9008', '314ee8cf', 'c4479dd3'],
#   ['b1f31cc0', '0d5c9008', 'c4479dd3', 'ec79b98a', 'e3610c01'],
#   ['2f4756d7', 'b8121ab6', 'ec79b98a', '5e043cfd', 'f151c2bb'],
#   ['2f4756d7', 'ec79b98a', 'b8121ab6', '5e043cfd', '37570bca'],
#   ['ec79b98a', 'fbdcafed', '0d5c9008', 'c4479dd3', 'b8121ab6'],
#   ['ec79b98a', 'e3610c01', '37570bca', '314ee8cf', '2f4756d7'],
#   ['ec79b98a', 'c4479dd3', '0d5c9008', 'b8121ab6', 'e3610c01'],
#   ['ec79b98a', 'b8121ab6', '78b8c86d', 'eefc3ee3', 'c4479dd3'],
#   ['ec79b98a', 'c4479dd3', '0d5c9008', 'e3610c01', '01f95cb6'],
#   ['0d5c9008', '37570bca', '01f95cb6', '6e3610c01', 'c95af011'],
#   ['0d5c9008', 'c4479dd3', 'e3610c01', '37570bca', '7d446dd6'],
#   ['0d5c9008', 'c4479dd3', '74123939', 'b8121ab6', '790a7ddb'],
#   ['0d5c9008', 'eefc3ee3', 'f7c6bf38', 'c4479dd3', '7e3610c01'],
#   ['0d5c9008', '01f95cb6', 'e3610c01', 'eefc3ee3', '37570bca'],
#   ['c4479dd3', '01f95cb6', 'fbdcafed', '8d5c9008', 'eefc3ee3'],
#   ['c4479dd3', 'e3610c01', 'f151c2bb', '0d5c9008', '01f95cb6'],
#   ['c4479dd3', 'e3610c01', '01f95cb6', '2f4756d7', 'b8121ab6'],
#   ['c4479dd3', 'fbdcafed', '0d5c9008', '01f95cb6', 'b8121ab6'],
#   ['c4479dd3', 'e3610c01', '2f4756d7', '78b8c86d', '314ee8cf'],
#   ['fbdcafed', '2f4756d7', 'bde8bc7c', 'd4e7a30b', '15542325'],
#   ['fbdcafed', 'c4479dd3', 'e3610c01', '37570bca', '01f95cb6'],
#   ['fbdcafed', 'e3610c01', 'ec79b98a', 'f7c6bf38', '79b8c86d'],
#   ['fbdcafed', 'ec79b98a', '78b8c86d', '01f95cb6', 'ea83195e'],
#   ['2f4756d7', '37570bca', 'b8121ab6', '01f95cb6', '653d264c'],
#   ['f151c2bb', 'eefc3ee3', 'd4e7a30b', '37570bca', '2f4756d7'],
#   ['37570bca', 'c4479dd3', '6b3e41cf', 'e3610c01', 'b8121ab6'],
#   ['f151c2bb', '37570bca', 'e3610c01', '0d5c9008', 'c4479dd3'],
#   ['eefc3ee3', '6a293a6d', 'e3610c01', 'f151c2bb', 'c4479dd3'],
#   ['f151c2bb', 'b8121ab6', '37570bca', '2f4756d7', '10c4479dd3'],
#   ['01f95cb6', 'f7c6bf38', 'c4479dd3', '0d5c9008', 'ec79b98a'],
#   ['01f95cb6', '6a293a6d', '4dcf8b35', '78b8c86d', '0b78fb57'],
#   ['01f95cb6', 'f7c6bf38', '469cc1f8', '7e1f87d6', 'b6c8bc8d'],
#   ['01f95cb6', 'f7c6bf38', 'eefc3ee3', 'bde8bc7c', 'd4e7a30b'],
#   ['01f95cb6', 'eefc3ee3', 'b8121ab6', '0d5c9008', '2f4756d7'],
#   ['bde8bc7c', 'eefc3ee3', 'd4e7a30b', '78b8c86d', 'f7c6bf38'],
#   ['bde8bc7c', 'd4e7a30b', 'eefc3ee3', '78b8c86d', '0eb46939'],
#   ['bde8bc7c', 'd4e7a30b', 'eefc3ee3', '78b8c86d', '314ee8cf'],
#   ['bde8bc7c', 'd4e7a30b', 'eefc3ee3', '78b8c86d', '01f95cb6'],
#   ['bde8bc7c', 'd4e7a30b', 'eefc3ee3', '314ee8cf', 'ea83195e'],
#   ['bde8bc7c', 'd4e7a30b', 'eefc3ee3', '78b8c86d', 'b8121ab6'],
#   ['d4e7a30b', 'eefc3ee3', '78b8c86d', 'bde8bc7c', 'f7c6bf38'],
#   ['d4e7a30b', '78b8c86d', '342037c3', 'c4479dd3', 'bde8bc7c'],
#   ['d4e7a30b', 'eefc3ee3', 'bde8bc7c', '314ee8cf', '78b8c86d'],
#   ['d4e7a30b', '78b8c86d', 'eefc3ee3', '314ee8cf', 'bde8bc7c'],
#   ['78b8c86d', 'eefc3ee3', '314ee8cf', 'd4e7a30b', 'bde8bc7c'],
#   ['78b8c86d', 'eefc3ee3', '314ee8cf', 'bde8bc7c', 'd4e7a30b'],
#   ['78b8c86d', '314ee8cf', 'eefc3ee3', '2e80fa3d', '0eb46939'],
#   ['78b8c86d', 'd4e7a30b', '314ee8cf', 'bde8bc7c', 'f7c6bf38'],
#   ['78b8c86d', '314ee8cf', 'ea83195e', '01f95cb6', 'f151c2bb'],
#   ['5e043cfd', 'b1f31cc0', 'f151c2bb', '0eb46939', '368caa05'],
#   ['37570bca', 'f151c2bb', '5e043cfd', '9e3610c01', 'eefc3ee3'],
#   ['37570bca', 'b1f31cc0', 'f151c2bb', 'b8121ab6', 'eefc3ee3'],
#   ['37570bca', '5e043cfd', '2f4756d7', '8eb46939', 'f151c2bb'],
#   ['37570bca', '0eb46939', 'f151c2bb', '5e043cfd', 'e3610c01'],
#   ['6a293a6d', '342037c3', '790a7ddb', 'd728141a', '1106b1dc'],
#   ['342037c3', '1106b1dc', '790a7ddb', '896d0dae', '6a293a6d'],
#   ['896d0dae', '342037c3', '790a7ddb', 'c95af011', 'bdf287a5'],
#   ['896d0dae', '1106b1dc', '6a293a6d', '342037c3', '943a92e0'],
#   ['790a7ddb', 'ad5b87dc', '7bfb63ba', '368caa05', 'ff50559b'],
#   ['aa9e24ac', '6a293a6d', '4dcf8b35', '342037c3', '9e41cc6b'],
#   ['aa9e24ac', '2ddb5f16', '5c920aad', 'ec79b98a', '9e41cc6b'],
#   ['aa9e24ac', '4dcf8b35', '9e41cc6b', '0f5525bd', 'b61f3a70'],
#   ['bdf287a5', '5c920aad', '33813c2c', '059738e5', 'b61f3a70'],
#   ['aa9e24ac', '4dcf8b35', '0f5525bd', 'd30e6624', '2ddb5f16'],
#   ['8d335987', 'aa9e24ac', '5c920aad', '9e41cc6b', 'bdf287a5'],
#   ['2ddb5f16', '9e41cc6b', '7e9de748', '943a92e0', 'ff50559b'],
#   ['84d8b35f', '1f9773b9', '0d8df57a', '2ddb5f16', 'ea07084a'],
#   ['84d8b35f', '1f9773b9', 'aa9e24ac', '5c920aad', '059738e5'],
#   ['84d8b35f', '1f9773b9', '790a7ddb', '314ee8cf', 'ff50559b'],
#   ['d30e6624', 'b61f3a70', '7e9de748', '2ddb5f16', '4dcf8b35'],
#   ['d30e6624', 'ff50559b', '9e31f48c', 'aa9f12bc', 'b5d1a5ec'],
#   ['d30e6624', '9e41cc6b', 'b61f3a70', '368caa05', '469cc1f8'],
#   ['2ddb5f16', 'd30e6624', '368caa05', '01f95cb6', '790a7ddb'],
#   ['d30e6624', '8d335987', '368caa05', '469cc1f8', 'a67ae3a0'],
#   ['a74246e6', '4dcf8b35', '6c146627', '2ddb5f16', 'ff50559b'],
#   ['2ddb5f16', '33813c2c', '7e9de748', '943a92e0', '0f5525bd'],
#   ['33813c2c', 'aa9e24ac', '2ddb5f16', 'a74246e6', '943a92e0'],
#   ['aa9e24ac', 'b61f3a70', '33813c2c', '7293f181', '0b78fb57'],
#   ['33813c2c', 'aa9e24ac', 'f018251f', '342037c3', 'd30e6624'],
#   ['ea07084a', 'a74246e6', '5c920aad', '7bfb63ba', '20bdbe32'],
#   ['ea07084a', '84d8b35f', '5c920aad', 'a67ae3a0', 'bf80eb5e'],
#   ['ea07084a', '469cc1f8', '2ddb5f16', 'a74246e6', '059738e5'],
#   ['ff50559b', 'a67ae3a0', 'bf244995', '4dcf8b35', '33813c2c'],
#   ['ea07084a', 'aa9e24ac', '469cc1f8', '653d264c', 'a67ae3a0'],
#   ['33813c2c', '0f5525bd', 'aa9e24ac', '943a92e0', 'a74246e6'],
#   ['33813c2c', '0f5525bd', '943a92e0', '7e9de748', '9e41cc6b'],
#   ['33813c2c', '943a92e0', '9e41cc6b', '469cc1f8', 'b61f3a70'],
#   ['33813c2c', '9e41cc6b', '6a293a6d', 'e8caa77b', '0b78fb57'],
#   ['33813c2c', 'f018251f', '943a92e0', 'e8caa77b', 'b61f3a70'],
#   ['a74246e6', 'b61f3a70', '8ff13c3e', '33813c2c', 'a18127c9'],
#   ['a67ae3a0', '7293f181', '059738e5', 'bf80eb5e', 'bdf287a5'],
#   ['a74246e6', '6a293a6d', '20bdbe32', '78b8c86d', '01f95cb6'],
#   ['a74246e6', '6c146627', '4dcf8b35', 'd30e6624', 'ea07084a'],
#   ['a74246e6', '5c920aad', 'bf244995', 'aa9e24ac', '33813c2c'],
#   ['1f9773b9', '84d8b35f', 'aa9e24ac', '20bdbe32', 'c950ef55'],
#   ['1f9773b9', '84d8b35f', 'ea07084a', '0d8df57a', '01f95cb6'],
#   ['059738e5', '943a92e0', '469cc1f8', '7e9de748', '7293f181'],
#   ['1f9773b9', '84d8b35f', '47ae523b', '059738e5', '2ddb5f16'],
#   ['1f9773b9', '84d8b35f', 'ea07084a', '5c920aad', 'b61f3a70'],
#   ['bf244995', 'a74246e6', '943a92e0', 'd30e6624', '6c146627'],
#   ['4dcf8b35', '6a293a6d', '8b8f0f38', 'b61f3a70', '2ddb5f16'],
#   ['bf244995', 'a74246e6', '9e41cc6b', 'd30e6624', '4dcf8b35'],
#   ['aa9e24ac', '469cc1f8', 'f018251f', 'a74246e6', '4dcf8b35'],
#   ['bf244995', 'ff50559b', 'ea07084a', '6c146627', 'd30e6624'],
#   ['0f5525bd', '2b0d81ee', '33813c2c', '6a293a6d', '47ae523b'],
#   ['4dcf8b35', 'eefc3ee3', '368caa05', '9e41cc6b', 'e8caa77b'],
#   ['0f5525bd', 'a67ae3a0', '33813c2c', '4dcf8b35', 'aa9e24ac'],
#   ['6f5525bd', '4dcf8b35', '2ddb5f16', '943a92e0', 'ce9623ca'],
#   ['0f5525bd', '2b0d81ee', '33813c2c', 'aa9e24ac', '9e41cc6b'],
#   ['4dcf8b35', '368caa05', 'ea07084a', 'ff50559b', '0d5c9008'],
#   ['368caa05', '4dcf8b35', '9d8bdfd2', 'c4479dd3', '314ee8cf'],
#   ['4dcf8b35', 'ff50559b', '0b78fb57', '9e41cc6b', '10ea07084a'],
#   ['4dcf8b35', '9e41cc6b', '2ddb5f16', '7e9de748', '01f95cb6'],
#   ['0f5525bd', '8bf80eb5e', '943a92e0', 'e55a6ace', '9e41cc6b'],
#   ['a67ae3a0', '0f5525bd', 'b61f3a70', 'ff50559b', '2b0d81ee'],
#   ['0f5525bd', 'b61f3a70', 'a67ae3a0', '368caa05', '790a7ddb'],
#   ['a67ae3a0', 'b61f3a70', '0f5525bd', '1f9773b9', '9f9773b9'],
#   ['a67ae3a0', '0f5525bd', 'b61f3a70', '368caa05', '4dcf8b35'],
#   ['b61f3a70', '2b0d81ee', 'a67ae3a0', '0f5525bd', 'ff50559b'],
#   ['47ae523b', 'b61f3a70', '2b0d81ee', 'a67ae3a0', '0f5525bd'],
#   ['47ae523b', 'b61f3a70', '2b0d81ee', '0f5525bd', '33813c2c'],
#   ['47ae523b', '0f5525bd', '2b0d81ee', 'b61f3a70', '33813c2c'],
#   ['47ae523b', 'b61f3a70', '2b0d81ee', '01f95cb6', '4dcf8b35'],
#   ['47ae523b', '0f5525bd', '2b0d81ee', 'b61f3a70', 'a67ae3a0'],
#   ['2b0d81ee', 'aa9e24ac', '0f5525bd', 'd30e6624', 'b61f3a70'],
#   ['2b0d81ee', '469cc1f8', '5c920aad', '01f95cb6', '78b8c86d'],
#   ['2b0d81ee', '0f5525bd', 'b61f3a70', '15542325', '653d264c'],
#   ['2b0d81ee', '0f5525bd', 'b61f3a70', '33813c2c', '47ae523b'],
#   ['2b0d81ee', 'd30e6624', '6a293a6d', '7293f181', 'aa9e24ac'],
#   ['059738e5', 'aa9e24ac', '0d8df57a', '7c7a4947', '469cc1f8'],
#   ['059738e5', '0d8df57a', 'aa9e24ac', '7c7a4947', '9f5525bd'],
#   ['059738e5', '0d8df57a', 'aa9e24ac', '5c920aad', '2ddb5f16'],
#   ['059738e5', '0d8df57a', '7c7a4947', 'aa9e24ac', '5c920aad'],
#   ['790a7ddb', '1106b1dc', '0b78fb57', 'e8caa77b', '2ddb5f16'],
#   ['aa9e24ac', '059738e5', '0d8df57a', '7e9de748', '2ddb5f16'],
#   ['0d8df57a', '059738e5', 'aa9e24ac', '2b0d81ee', '368caa05'],
#   ['059738e5', '0d8df57a', '5c920aad', 'aa9e24ac', 'd30e6624'],
#   ['059738e5', '0d8df57a', 'aa9e24ac', '2ddb5f16', 'bdf287a5'],
#   ['059738e5', '0d8df57a', '7c7a4947', 'aa9e24ac', 'ce9623ca'],
#   ['5c920aad', '2b0d81ee', 'aa9e24ac', '059738e5', '0d8df57a'],
#   ['5c920aad', 'a74246e6', '6c146627', 'bf244995', 'ea07084a'],
#   ['059738e5', 'a74246e6', '6c146627', '0e8ded0c', 'aa9e24ac'],
#   ['5c920aad', '059738e5', 'aa9e24ac', '20bdbe32', '0d8df57a'],
#   ['5c920aad', 'aa9e24ac', '6c146627', 'f018251f', '20bdbe32'],
#   ['bf80eb5e', '15542325', '653d264c', '51a23b03', 'd261a76e'],
#   ['bf80eb5e', '51a23b03', 'ea07084a', '7293f181', '7e9de748'],
#   ['bf80eb5e', '368caa05', 'fc0dd85c', '74123939', '6a293a6d'],
#   ['7acd2acc', 'bf80eb5e', '653d264c', 'e3610c01', 'ec79b98a'],
#   ['d261a76e', 'ff50559b', '2f4756d7', 'ff50559b', '943a92e0'],
#   ['fc0dd85c', 'a74246e6', 'bf80eb5e', '368caa05', 'd261a76e'],
#   ['fc0dd85c', 'bf80eb5e', '653d264c', '74123939', '368caa05'],
#   ['fc0dd85c', 'a74246e6', '368caa05', '0d8df57a', '5c920aad'],
#   ['bf80eb5e', 'fc0dd85c', '7bfb63ba', 'd261a76e', '7293f181'],
#   ['fc0dd85c', 'ff50559b', 'aa9e24ac', '896d0dae', '7293f181'],
#   ['653d264c', '368caa05', '74123939', 'bf80eb5e', 'f1be8bd4'],
#   ['7bfb63ba', '6a77c974', '653d264c', '8a5d729e', 'af8c572c'],
#   ['7bfb63ba', '342037c3', 'f1be8bd4', '8a07084a', '6a293a6d'],
#   ['7bfb63ba', 'f1be8bd4', '15542325', '78b8c86d', 'bdf287a5'],
#   ['7293f181', '51a23b03', '20bdbe32', '15542325', '059738e5'],
#   ['7293f181', '51a23b03', '15542325', '368caa05', 'bdf287a5'],
#   ['342037c3', '01f95cb6', '20bdbe32', 'bdf287a5', '059738e5'],
#   ['51a23b03', '0e8ded0c', '15542325', '20bdbe32', '6a293a6d'],
#   ['7293f181', '01f95cb6', '4dcf8b35', '8e41cc6b', '943a92e0'],
#   ['7293f181', 'b61f3a70', '01f95cb6', '15542325', '74123939'],
#   ['20bdbe32', '51a23b03', '01f95cb6', 'f1be8bd4', '653d264c'],
#   ['368caa05', '20bdbe32', '7acd2acc', '9e41cc6b', '5e043cfd'],
#   ['20bdbe32', '368caa05', '653d264c', 'bdf287a5', 'a67ae3a0'],
#   ['20bdbe32', '7bfb63ba', '5c920aad', '342037c3', 'aa9e24ac'],
#   ['20bdbe32', '5c920aad', 'bf80eb5e', '7bfb63ba', '368caa05'],
#   ['15542325', '7293f181', '314ee8cf', '20bdbe32', '6a293a6d'],
#   ['15542325', 'a67ae3a0', '01f95cb6', '7293f181', 'bdf287a5'],
#   ['20bdbe32', '15542325', '51a23b03', '7293f181', '01f95cb6'],
#   ['15542325', 'b61f3a70', '51a23b03', '368caa05', 'eefc3ee3'],
#   ['15542325', '2b0d81ee', '5a23b03', '653d264c', 'd261a76e'],
#   ['51a23b03', 'd261a76e', '2b0d81ee', 'bf80eb5e', '15542325'],
#   ['51a23b03', '6a293a6d', '01f95cb6', '1106b1dc', '342037c3'],
#   ['51a23b03', '15542325', '01f95cb6', '368caa05', 'd261a76e'],
#   ['15542325', '51a23b03', '2b0d81ee', '78b8c86d', '342037c3'],
#   ['d261a76e', '15542325', '7bfb63ba', '6a293a6d', '7293f181'],
#   ['0e8ded0c', '368caa05', '01f95cb6', 'b1f31cc0', 'ee3ee3'],
#   ['0e8ded0c', '51a23b03', '2b0d81ee', 'bf80eb5e', 'a67ae3a0'],
#   ['51a23b03', '0e8ded0c', '7293f181', '9e41cc6b', '78b8c86d'],
#   ['0f5525bd', '2b0d81ee', '790a7ddb', '8d4f9ceb', 'f3c27bc4'],
#   ['0e8ded0c', '51a23b03', 'd728141a', 'bdf287a5', '790a7ddb'],
#   ['6a293a6d', '74123939', 'bdf287a5', '2f4756d7', '1106b1dc'],
#   ['368caa05', '15542325', '6a293a6d', 'bf80eb5e', '51a23b03'],
#   ['6a293a6d', 'd261a76e', '943a92e0', 'a74246e6', '1106b1dc'],
#   ['6a293a6d', '2b0d81ee', '84d8b35f', '943a92e0', '4dcf8b35'],
#   ['6a293a6d', 'a67ae3a0', '84d8b35f', '314ee8cf', '943a92e0'],
#   ['368caa05', 'd261a76e', 'a67ae3a0', 'b61f3a70', '469cc1f8'],
#   ['368caa05', '74123939', '15542325', '7bfb63ba', '84d8b35f'],
#   ['368caa05', 'a67ae3a0', '653d264c', '7293f181', 'aa9e24ac'],
#   ['368caa05', 'd261a76e', '0f5525bd', 'b8121ab6', '9e41cc6b'],
#   ['368caa05', 'd30e6624', '4dcf8b35', '01f95cb6', '33813c2c'],
#   ['368caa05', '01f95cb6', 'b61f3a70', '4dcf8b35', '790a7ddb'],
#   ['368caa05', '01f95cb6', 'bde8bc7c', 'd4e7a30b', 'bdf287a5'],
#   ['790a7ddb', 'd728141a', '943a92e0', 'bdf287a5', '1106b1dc'],
#   ['15542325', 'd261a76e', '9e41cc6b', 'a74246e6', '4dcf8b35'],
#   ['2ddb5f16', 'b61f3a70', '01f95cb6', '78b8c86d', '4dcf8b35'],
#   ['653d264c', '74123939', 'f1be8bd4', '368caa05', '15542325'],
#   ['653d264c', '74123939', 'f1be8bd4', '6a293a6d', '368caa05'],
#   ['653d264c', 'f1be8bd4', '74123939', '9c95af011', '5c920aad'],
#   ['653d264c', '368caa05', '7293f181', 'd261a76e', '74123939'],
#   ['653d264c', '74123939', '368caa05', 'f1be8bd4', '6a293a6d'],
#   ['01f95cb6', '15542325', '6a293a6d', '20bdbe32', '74123939'],
#   ['f1be8bd4', '7bfb63ba', '20bdbe32', '7293f181', '15542325'],
#   ['653d264c', '74123939', '7bfb63ba', '15542325', '6a293a6d'],
#   ['f1be8bd4', 'aa9e24ac', '790a7ddb', '7293f181', '059738e5'],
#   ['f1be8bd4', '74123939', '653d264c', '5c920aad', 'ea07084a'],
#   ['74123939', '7293f181', '7e9de748', '01f95cb6', '37570bca'],
#   ['653d264c', '74123939', 'f1be8bd4', '15542325', '6a293a6d'],
#   ['74123939', '653d264c', '15542325', 'f1be8bd4', 'b61f3a70'],
#   ['7293f181', 'f1be8bd4', '653d264c', '74123939', 'bf80eb5e'],
#   ['74123939', '653d264c', '368caa05', 'f1be8bd4', '15542325']],
#  'relevance_total': [[True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, True],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, True, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, True, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, True, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [False, True, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, True, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, False, False, False, False],
#   [False, True, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [True, False, False, False, False],
#   [False, True, False, False, False],
#   [True, False, False, False, False],
#   [False, False, False, True, False],
#   [True, False, False, False, False]],
#  'hit_rate': 0.8376288659793815,
#  'mrr': 0.7984106529209622}

# %%
print(res_reranking_more_options['hit_rate'])
print(res_reranking_more_options['mrr'])
# Out:
# 0.8376288659793815
# 0.7984106529209622

# %% [markdown]
# It's still better. We shall use this approach in the final application.
